# %%
import pandas as pd
import numpy as np
import xml.etree.ElementTree as ET
import datetime as dt

# %% [markdown]
# ----
# ### Import CSVs from Whoop

# %%
physio = pd.read_csv(r'/Users/tinym/Desktop/my_whoop_data_2022_11_28/physiological_cycles.csv')

# %%
physio.columns
# Out:
# Index(['Cycle start time', 'Cycle end time', 'Cycle timezone',
#        'Recovery score %', 'Resting heart rate (bpm)',
#        'Heart rate variability (ms)', 'Skin temp (celsius)', 'Blood oxygen %',
#        'Day Strain', 'Energy burned (cal)', 'Max HR (bpm)', 'Average HR (bpm)',
#        'Sleep onset', 'Wake onset', 'Sleep performance %',
#        'Respiratory rate (rpm)', 'Asleep duration (min)',
#        'In bed duration (min)', 'Light sleep duration (min)',
#        'Deep (SWS) duration (min)', 'REM duration (min)',
#        'Awake duration (min)', 'Sleep need (min)', 'Sleep debt (min)',
#        'Sleep efficiency %'],
#       dtype='object')

# %%
physio.head()
# Out:
#       Cycle start time       Cycle end time Cycle timezone  Recovery score %  \
# 0  2022-11-28 01:03:57                  NaN      UTC+01:00              65.0
# 1  2022-11-27 03:18:18  2022-11-28 01:03:57      UTC+01:00              36.0
# 2  2022-11-26 03:51:55  2022-11-27 03:18:18      UTC+01:00              42.0
# 3  2022-11-25 03:24:54  2022-11-26 03:51:55      UTC+01:00              45.0
# 4  2022-11-24 03:17:20  2022-11-25 03:24:54      UTC+01:00              53.0
#
#    Resting heart rate (bpm)  Heart rate variability (ms)  Skin temp (celsius)  \
# 0                      61.0                         56.0                33.20
# 1                      65.0                         47.0                33.74
# 2                      61.0                         50.0                33.60
# 3                      58.0                         52.0                33.90
# 4                      59.0                         56.0                32.10
#
#    Blood oxygen %  Day Strain  Energy burned (cal)  ...  \
# 0           97.67         NaN                  NaN  ...
# 1           95.24         5.0               1740.0  ...
# 2           97.17        13.5               2651.0  ...
# 3           97.07        14.8               2984.0  ...
# 4           98.25         8.2               2121.0  ...
#
#    Respiratory rate (rpm)  Asleep duration (min) In bed duration (min)  \
# 0                    13.2                  402.0                 427.0
# 1                    13.4                  413.0                 447.0
# 2                    13.5                  426.0                 464.0
# 3                    13.0                  435.0                 512.0
# 4                    13.2                  470.0                 522.0
#
#   Light sleep duration (min)  Deep (SWS) duration (min)  REM duration (min)  \
# 0                      219.0                       90.0                93.0
# 1                      218.0                       88.0               107.0
# 2                      187.0                      109.0               130.0
# 3                      200.0                      107.0               128.0
# 4                      244.0                      111.0               115.0
#
#    Awake duration (min)  Sleep need (min)  Sleep debt (min)  \
# 0                  25.0             528.0              56.0
# 1                  34.0             543.0              46.0
# 2                  38.0             535.0              30.0
# 3                  77.0             500.0              23.0
# 4                  52.0             523.0              51.0
#
#    Sleep efficiency %
# 0                96.0
# 1                92.0
# 2                92.0
# 3                85.0
# 4                90.0
#
# [5 rows x 25 columns]

# %%
physio.shape
# Out:
# (679, 25)

# %%
sleep = pd.read_csv(r'/Users/tinym/Desktop/my_whoop_data_2022_11_28/sleeps.csv')

# %%
sleep.shape
# Out:
# (712, 17)

# %%
sleep.head()
# Out:
#       Cycle start time       Cycle end time Cycle timezone  \
# 0  2022-11-28 01:03:57                  NaN      UTC+01:00
# 1  2022-11-27 03:18:18  2022-11-28 01:03:57      UTC+01:00
# 2  2022-11-26 03:51:55  2022-11-27 03:18:18      UTC+01:00
# 3  2022-11-25 03:24:54  2022-11-26 03:51:55      UTC+01:00
# 4  2022-11-24 03:17:20  2022-11-25 03:24:54      UTC+01:00
#
#            Sleep onset           Wake onset  Sleep performance %  \
# 0  2022-11-28 01:03:57  2022-11-28 08:11:16                 76.0
# 1  2022-11-27 03:18:18  2022-11-27 10:52:02                 76.0
# 2  2022-11-26 03:51:55  2022-11-26 11:36:43                 80.0
# 3  2022-11-25 03:24:54  2022-11-25 11:58:44                 87.0
# 4  2022-11-24 03:17:20  2022-11-24 11:59:53                 90.0
#
#    Respiratory rate (rpm)  Asleep duration (min)  In bed duration (min)  \
# 0                    13.2                  402.0                  427.0
# 1                    13.4                  413.0                  447.0
# 2                    13.5                  426.0                  464.0
# 3                    13.0                  435.0                  512.0
# 4                    13.2                  470.0                  522.0
#
#    Light sleep duration (min)  Deep (SWS) duration (min)  REM duration (min)  \
# 0                       219.0                       90.0                93.0
# 1                       218.0                       88.0               107.0
# 2                       187.0                      109.0               130.0
# 3                       200.0                      107.0               128.0
# 4                       244.0                      111.0               115.0
#
#    Awake duration (min)  Sleep need (min)  Sleep debt (min)  \
# 0                  25.0             528.0              56.0
# 1                  34.0             543.0              46.0
# 2                  38.0             535.0              30.0
# 3                  77.0             500.0              23.0
# 4                  52.0             523.0              51.0
#
#    Sleep efficiency %    Nap
# 0                96.0  False
# 1                92.0  False
# 2                92.0  False
# 3                85.0  False
# 4                90.0  False

# %%
workout = pd.read_csv(r'/Users/tinym/Desktop/my_whoop_data_2022_11_28/workouts.csv')

# %%
workout.shape
# Out:
# (133, 20)

# %%
workout.dtypes
# Out:
# Cycle start time             object
# Cycle end time               object
# Cycle timezone               object
# Workout start time           object
# Workout end time             object
# Duration (min)                int64
# Activity name                object
# Activity Strain             float64
# Energy burned (cal)         float64
# Max HR (bpm)                float64
# Average HR (bpm)            float64
# HR Zone 1 %                 float64
# HR Zone 2 %                 float64
# HR Zone 3 %                 float64
# HR Zone 4 %                 float64
# HR Zone 5 %                 float64
# GPS enabled                    bool
# Distance (meters)           float64
# Altitude gain (meters)      float64
# Altitude change (meters)    float64
# dtype: object

# %%
workout['Energy burned (cal)'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
workout.loc[workout['Activity name'] == 'Surfing'].head()
# Out:
#         Cycle start time       Cycle end time Cycle timezone  \
# 116  2020-05-22 03:10:50  2020-05-23 00:03:00      UTC-04:00
#
#       Workout start time     Workout end time  Duration (min) Activity name  \
# 116  2020-05-22 15:54:41  2020-05-22 16:20:52              26       Surfing
#
#      Activity Strain  Energy burned (cal)  Max HR (bpm)  Average HR (bpm)  \
# 116              9.2                287.0         174.0             147.0
#
#      HR Zone 1 %  HR Zone 2 %  HR Zone 3 %  HR Zone 4 %  HR Zone 5 %  \
# 116          0.0          2.0         14.0         49.0         33.0
#
#      GPS enabled  Distance (meters)  Altitude gain (meters)  \
# 116        False                NaN                     NaN
#
#      Altitude change (meters)
# 116                       NaN

# %%
workout.head(10)
# Out:
#       Cycle start time       Cycle end time Cycle timezone  \
# 0  2022-11-25 03:24:54  2022-11-26 03:51:55      UTC+01:00
# 1  2022-11-10 00:48:31  2022-11-10 23:39:33      UTC+01:00
# 2  2022-11-08 23:48:24  2022-11-10 00:48:31      UTC+01:00
# 3  2022-11-05 03:03:31  2022-11-06 00:38:48      UTC+01:00
# 4  2022-10-29 00:19:26  2022-10-30 01:33:11      UTC+02:00
# 5  2022-10-22 02:50:19  2022-10-23 03:18:23      UTC+02:00
# 6  2022-10-18 01:04:41  2022-10-19 00:35:54      UTC+02:00
# 7  2022-10-17 00:07:54  2022-10-18 01:04:41      UTC+02:00
# 8  2022-10-03 02:02:48  2022-10-04 01:43:57      UTC+01:00
# 9  2022-09-07 01:15:28  2022-09-07 23:59:02      UTC+03:00
#
#     Workout start time     Workout end time  Duration (min)  \
# 0  2022-11-26 01:33:32  2022-11-26 02:02:47              29
# 1  2022-11-10 16:31:49  2022-11-10 17:20:04              48
# 2  2022-11-09 16:00:00  2022-11-09 17:00:00              60
# 3  2022-11-05 14:20:53  2022-11-05 15:35:49              74
# 4  2022-10-29 19:58:53  2022-10-29 20:50:06              51
# 5  2022-10-22 21:56:35  2022-10-22 22:45:51              49
# 6  2022-10-18 20:42:31  2022-10-18 21:44:56              62
# 7  2022-10-17 21:08:16  2022-10-17 21:26:59              18
# 8  2022-10-03 20:06:00  2022-10-03 20:37:35              31
# 9  2022-09-07 18:16:56  2022-09-07 19:21:37              64
#
#         Activity name  Activity Strain  Energy burned (cal)  Max HR (bpm)  \
# 0            Activity              8.4                284.0         159.0
# 1  Functional Fitness              8.3                335.0         172.0
# 2  Functional Fitness              9.7                431.0         188.0
# 3       Weightlifting             12.2                674.0         169.0
# 4             Running             11.2                475.0         191.0
# 5            Activity             10.2                445.0         172.0
# 6  Functional Fitness             11.4                531.0         187.0
# 7             Running              7.5                184.0         181.0
# 8             Cycling              8.7                308.0         166.0
# 9            Swimming             10.8                540.0         169.0
#
#    Average HR (bpm)  HR Zone 1 %  HR Zone 2 %  HR Zone 3 %  HR Zone 4 %  \
# 0             140.0          0.0          1.0         35.0         62.0
# 1             127.0          0.0         16.0         60.0         18.0
# 2             128.0          0.0         22.0         49.0         20.0
# 3             137.0          0.0          3.0         40.0         52.0
# 4             138.0          0.0          3.0         41.0         31.0
# 5             138.0          1.0          3.0         28.0         57.0
# 6             137.0          0.0         17.0         22.0         44.0
# 7             143.0          0.0          4.0         25.0         34.0
# 8             141.0          0.0          4.0         14.0         77.0
# 9             135.0          0.0          3.0         38.0         53.0
#
#    HR Zone 5 %  GPS enabled  Distance (meters)  Altitude gain (meters)  \
# 0          0.0        False                NaN                     NaN
# 1          4.0        False                NaN                     NaN
# 2          5.0        False                NaN                     NaN
# 3          2.0        False                NaN                     NaN
# 4         20.0        False                NaN                     NaN
# 5          8.0        False                NaN                     NaN
# 6         14.0        False                NaN                     NaN
# 7         31.0         True            1891.35                   40.24
# 8          3.0        False                NaN                     NaN
# 9          3.0        False                NaN                     NaN
#
#    Altitude change (meters)
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                     -2.75
# 8                       NaN
# 9                       NaN

# %% [markdown]
# ----
# ### Import XMLs from Apple Health

# %%
# create element tree object 
tree = ET.parse(r'/Users/tinym/Desktop/apple_health_export/export.xml') 

# for every health record, extract the attributes into a dictionary (columns). Then create a list (rows).
root = tree.getroot()

# %%
record_list = [x.attrib for x in root.iter('Record')]

# create DataFrame from a list (rows) of dictionaries (columns)
data = pd.DataFrame(record_list)

# proper type to dates
for col in ['creationDate', 'startDate', 'endDate']:
    data[col] = pd.to_datetime(data[col])

# value is numeric, NaN if fails
data['value'] = pd.to_numeric(data['value'], errors='coerce')

# %%
# some records do not measure anything, just count occurences
# filling with 1.0 (= one time) makes it easier to aggregate
data['value'] = data['value'].fillna(1.0)

# shorter observation names
data['type'] = data['type'].str.replace('HKQuantityTypeIdentifier', '')
data['type'] = data['type'].str.replace('HKCategoryTypeIdentifier', '')
data.head()
# Out:
#             type sourceName sourceVersion  \
# 0  BodyMassIndex   FitTrack          1590
# 1  BodyMassIndex   FitTrack          1590
# 2  BodyMassIndex   FitTrack          1590
# 3  BodyMassIndex    Lifesum             1
# 4         Height      JEFIT          1449
#
#                                               device   unit  \
# 0  <<HKDevice: 0x2815a18b0>, name:ios, manufactur...  count
# 1  <<HKDevice: 0x2815a18b0>, name:ios, manufactur...  count
# 2  <<HKDevice: 0x2815a18b0>, name:ios, manufactur...  count
# 3                                                NaN  count
# 4                                                NaN     ft
#
#                creationDate                 startDate  \
# 0 2022-02-19 18:56:11+01:00 2022-02-19 18:56:10+01:00
# 1 2022-02-19 18:56:11+01:00 2022-02-19 18:56:10+01:00
# 2 2022-02-19 18:56:11+01:00 2022-02-19 18:56:10+01:00
# 3 2022-06-16 18:27:17+01:00 2022-06-16 13:22:23+01:00
# 4 2020-02-25 07:25:44+01:00 2020-02-25 07:25:44+01:00
#
#                     endDate    value
# 0 2022-02-19 18:56:10+01:00  23.6000
# 1 2022-02-19 18:56:10+01:00  23.6000
# 2 2022-02-19 18:56:10+01:00  23.6000
# 3 2022-06-16 13:22:23+01:00  24.1478
# 4 2020-02-25 07:25:44+01:00   5.8750

# %%
data.type.unique()
# Out:
# array(['BodyMassIndex', 'Height', 'BodyMass', 'HeartRate',
#        'OxygenSaturation', 'RespiratoryRate', 'BodyFatPercentage',
#        'LeanBodyMass', 'StepCount', 'DistanceWalkingRunning',
#        'BasalEnergyBurned', 'ActiveEnergyBurned', 'FlightsClimbed',
#        'DietaryFatTotal', 'DietaryFatMonounsaturated',
#        'DietaryFatSaturated', 'DietaryCholesterol', 'DietarySodium',
#        'DietaryCarbohydrates', 'DietaryFiber', 'DietarySugar',
#        'DietaryEnergyConsumed', 'DietaryProtein', 'DietaryVitaminA',
#        'DietaryVitaminB6', 'DietaryVitaminC', 'DietaryVitaminD',
#        'DietaryVitaminE', 'DietaryVitaminK', 'DietaryCalcium',
#        'DietaryIron', 'DietaryThiamin', 'DietaryRiboflavin',
#        'DietaryNiacin', 'DietaryPhosphorus', 'DietaryMagnesium',
#        'DietaryZinc', 'DietarySelenium', 'DietaryCopper',
#        'DietaryManganese', 'DietaryPotassium', 'RestingHeartRate',
#        'HeadphoneAudioExposure', 'WalkingDoubleSupportPercentage',
#        'WalkingSpeed', 'WalkingStepLength', 'WalkingAsymmetryPercentage',
#        'HKDataTypeSleepDurationGoal', 'AppleWalkingSteadiness',
#        'SleepAnalysis', 'MindfulSession'], dtype=object)

# %%
hr = data.loc[data.type == 'HeartRate']

# %%
hr.shape
# Out:
# (1960018, 9)

# %%
hr.dtypes
# Out:
# type                                           object
# sourceName                                     object
# sourceVersion                                  object
# device                                         object
# unit                                           object
# creationDate     datetime64[ns, pytz.FixedOffset(60)]
# startDate        datetime64[ns, pytz.FixedOffset(60)]
# endDate          datetime64[ns, pytz.FixedOffset(60)]
# value                                         float64
# dtype: object

# %%
hr.sort_values(by='value', ascending=False).tail(50)
# Out:
#               type                     sourceName sourceVersion  \
# 1147442  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1147852  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1147853  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1147854  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1147855  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1147856  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1147857  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1147441  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1147440  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1147439  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1147438  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1147152  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1149669  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1149668  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1149667  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1149671  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1148319  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 959282   HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1149193  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1147652  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1147660  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1147661  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1147662  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1149200  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1149199  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1149198  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1149197  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 959281   HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1149195  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1149194  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1149196  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 959279   HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 959256   HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 959280   HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1148314  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 959278   HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 959257   HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1147663  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1148318  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1148317  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1148316  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1148315  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1147659  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1147658  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1147655  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1147654  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1147653  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1149670  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1147657  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1147656  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
#
#                                                     device       unit  \
# 1147442  <<HKDevice: 0x281589d60>, name:WHOOP 3A097270,...  count/min
# 1147852  <<HKDevice: 0x281588500>, name:WHOOP 3A097270,...  count/min
# 1147853  <<HKDevice: 0x281588500>, name:WHOOP 3A097270,...  count/min
# 1147854  <<HKDevice: 0x281588500>, name:WHOOP 3A097270,...  count/min
# 1147855  <<HKDevice: 0x281588500>, name:WHOOP 3A097270,...  count/min
# 1147856  <<HKDevice: 0x281588500>, name:WHOOP 3A097270,...  count/min
# 1147857  <<HKDevice: 0x281588500>, name:WHOOP 3A097270,...  count/min
# 1147441  <<HKDevice: 0x281589d60>, name:WHOOP 3A097270,...  count/min
# 1147440  <<HKDevice: 0x281589d60>, name:WHOOP 3A097270,...  count/min
# 1147439  <<HKDevice: 0x281589d60>, name:WHOOP 3A097270,...  count/min
# 1147438  <<HKDevice: 0x281589d60>, name:WHOOP 3A097270,...  count/min
# 1147152  <<HKDevice: 0x28158acb0>, name:WHOOP 3A097270,...  count/min
# 1149669  <<HKDevice: 0x281589a90>, name:WHOOP 3A097270,...  count/min
# 1149668  <<HKDevice: 0x281589a90>, name:WHOOP 3A097270,...  count/min
# 1149667  <<HKDevice: 0x281589a90>, name:WHOOP 3A097270,...  count/min
# 1149671  <<HKDevice: 0x281589a90>, name:WHOOP 3A097270,...  count/min
# 1148319  <<HKDevice: 0x28158bd40>, name:WHOOP 3A097270,...  count/min
# 959282   <<HKDevice: 0x28154f430>, name:WHOOP 3A097270,...  count/min
# 1149193  <<HKDevice: 0x2815d3e80>, name:WHOOP 3A097270,...  count/min
# 1147652  <<HKDevice: 0x281588500>, name:WHOOP 3A097270,...  count/min
# 1147660  <<HKDevice: 0x281588500>, name:WHOOP 3A097270,...  count/min
# 1147661  <<HKDevice: 0x281588500>, name:WHOOP 3A097270,...  count/min
# 1147662  <<HKDevice: 0x281588500>, name:WHOOP 3A097270,...  count/min
# 1149200  <<HKDevice: 0x2815d3e80>, name:WHOOP 3A097270,...  count/min
# 1149199  <<HKDevice: 0x2815d3e80>, name:WHOOP 3A097270,...  count/min
# 1149198  <<HKDevice: 0x2815d3e80>, name:WHOOP 3A097270,...  count/min
# 1149197  <<HKDevice: 0x2815d3e80>, name:WHOOP 3A097270,...  count/min
# 959281   <<HKDevice: 0x28154f430>, name:WHOOP 3A097270,...  count/min
# 1149195  <<HKDevice: 0x2815d3e80>, name:WHOOP 3A097270,...  count/min
# 1149194  <<HKDevice: 0x2815d3e80>, name:WHOOP 3A097270,...  count/min
# 1149196  <<HKDevice: 0x2815d3e80>, name:WHOOP 3A097270,...  count/min
# 959279   <<HKDevice: 0x28154f430>, name:WHOOP 3A097270,...  count/min
# 959256   <<HKDevice: 0x28154f430>, name:WHOOP 3A097270,...  count/min
# 959280   <<HKDevice: 0x28154f430>, name:WHOOP 3A097270,...  count/min
# 1148314  <<HKDevice: 0x28158bd40>, name:WHOOP 3A097270,...  count/min
# 959278   <<HKDevice: 0x28154f430>, name:WHOOP 3A097270,...  count/min
# 959257   <<HKDevice: 0x28154f430>, name:WHOOP 3A097270,...  count/min
# 1147663  <<HKDevice: 0x281588500>, name:WHOOP 3A097270,...  count/min
# 1148318  <<HKDevice: 0x28158bd40>, name:WHOOP 3A097270,...  count/min
# 1148317  <<HKDevice: 0x28158bd40>, name:WHOOP 3A097270,...  count/min
# 1148316  <<HKDevice: 0x28158bd40>, name:WHOOP 3A097270,...  count/min
# 1148315  <<HKDevice: 0x28158bd40>, name:WHOOP 3A097270,...  count/min
# 1147659  <<HKDevice: 0x281588500>, name:WHOOP 3A097270,...  count/min
# 1147658  <<HKDevice: 0x281588500>, name:WHOOP 3A097270,...  count/min
# 1147655  <<HKDevice: 0x281588500>, name:WHOOP 3A097270,...  count/min
# 1147654  <<HKDevice: 0x281588500>, name:WHOOP 3A097270,...  count/min
# 1147653  <<HKDevice: 0x281588500>, name:WHOOP 3A097270,...  count/min
# 1149670  <<HKDevice: 0x281589a90>, name:WHOOP 3A097270,...  count/min
# 1147657  <<HKDevice: 0x281588500>, name:WHOOP 3A097270,...  count/min
# 1147656  <<HKDevice: 0x281588500>, name:WHOOP 3A097270,...  count/min
#
#                      creationDate                 startDate  \
# 1147442 2021-10-07 09:49:36+01:00 2021-10-07 09:49:35+01:00
# 1147852 2021-10-07 09:55:03+01:00 2021-10-07 09:55:03+01:00
# 1147853 2021-10-07 09:55:05+01:00 2021-10-07 09:55:04+01:00
# 1147854 2021-10-07 09:55:05+01:00 2021-10-07 09:55:04+01:00
# 1147855 2021-10-07 09:55:06+01:00 2021-10-07 09:55:05+01:00
# 1147856 2021-10-07 09:55:06+01:00 2021-10-07 09:55:06+01:00
# 1147857 2021-10-07 09:55:08+01:00 2021-10-07 09:55:07+01:00
# 1147441 2021-10-07 09:49:34+01:00 2021-10-07 09:49:34+01:00
# 1147440 2021-10-07 09:49:34+01:00 2021-10-07 09:49:33+01:00
# 1147439 2021-10-07 09:49:33+01:00 2021-10-07 09:49:32+01:00
# 1147438 2021-10-07 09:49:33+01:00 2021-10-07 09:49:32+01:00
# 1147152 2021-10-07 09:45:44+01:00 2021-10-07 09:45:43+01:00
# 1149669 2021-10-07 10:19:17+01:00 2021-10-07 10:19:16+01:00
# 1149668 2021-10-07 10:19:16+01:00 2021-10-07 10:19:16+01:00
# 1149667 2021-10-07 10:19:16+01:00 2021-10-07 10:19:15+01:00
# 1149671 2021-10-07 10:19:19+01:00 2021-10-07 10:19:18+01:00
# 1148319 2021-10-07 10:01:17+01:00 2021-10-07 10:01:16+01:00
# 959282  2021-10-05 11:48:21+01:00 2021-10-05 11:48:21+01:00
# 1149193 2021-10-07 10:12:56+01:00 2021-10-07 10:12:55+01:00
# 1147652 2021-10-07 09:52:23+01:00 2021-10-07 09:52:23+01:00
# 1147660 2021-10-07 09:52:29+01:00 2021-10-07 09:52:29+01:00
# 1147661 2021-10-07 09:52:31+01:00 2021-10-07 09:52:30+01:00
# 1147662 2021-10-07 09:52:31+01:00 2021-10-07 09:52:31+01:00
# 1149200 2021-10-07 10:13:01+01:00 2021-10-07 10:13:01+01:00
# 1149199 2021-10-07 10:13:01+01:00 2021-10-07 10:13:00+01:00
# 1149198 2021-10-07 10:13:00+01:00 2021-10-07 10:12:59+01:00
# 1149197 2021-10-07 10:13:00+01:00 2021-10-07 10:12:59+01:00
# 959281  2021-10-05 11:48:21+01:00 2021-10-05 11:48:20+01:00
# 1149195 2021-10-07 10:12:57+01:00 2021-10-07 10:12:57+01:00
# 1149194 2021-10-07 10:12:57+01:00 2021-10-07 10:12:56+01:00
# 1149196 2021-10-07 10:12:59+01:00 2021-10-07 10:12:58+01:00
# 959279  2021-10-05 11:48:20+01:00 2021-10-05 11:48:19+01:00
# 959256  2021-10-05 11:48:01+01:00 2021-10-05 11:48:00+01:00
# 959280  2021-10-05 11:48:20+01:00 2021-10-05 11:48:20+01:00
# 1148314 2021-10-07 10:01:13+01:00 2021-10-07 10:01:12+01:00
# 959278  2021-10-05 11:48:18+01:00 2021-10-05 11:48:18+01:00
# 959257  2021-10-05 11:48:02+01:00 2021-10-05 11:48:01+01:00
# 1147663 2021-10-07 09:52:33+01:00 2021-10-07 09:52:32+01:00
# 1148318 2021-10-07 10:01:16+01:00 2021-10-07 10:01:16+01:00
# 1148317 2021-10-07 10:01:16+01:00 2021-10-07 10:01:15+01:00
# 1148316 2021-10-07 10:01:14+01:00 2021-10-07 10:01:14+01:00
# 1148315 2021-10-07 10:01:14+01:00 2021-10-07 10:01:13+01:00
# 1147659 2021-10-07 09:52:29+01:00 2021-10-07 09:52:28+01:00
# 1147658 2021-10-07 09:52:28+01:00 2021-10-07 09:52:28+01:00
# 1147655 2021-10-07 09:52:26+01:00 2021-10-07 09:52:25+01:00
# 1147654 2021-10-07 09:52:25+01:00 2021-10-07 09:52:24+01:00
# 1147653 2021-10-07 09:52:25+01:00 2021-10-07 09:52:23+01:00
# 1149670 2021-10-07 10:19:17+01:00 2021-10-07 10:19:17+01:00
# 1147657 2021-10-07 09:52:28+01:00 2021-10-07 09:52:27+01:00
# 1147656 2021-10-07 09:52:26+01:00 2021-10-07 09:52:26+01:00
#
#                           endDate  value
# 1147442 2021-10-07 09:49:35+01:00   46.0
# 1147852 2021-10-07 09:55:03+01:00   46.0
# 1147853 2021-10-07 09:55:04+01:00   46.0
# 1147854 2021-10-07 09:55:04+01:00   46.0
# 1147855 2021-10-07 09:55:05+01:00   46.0
# 1147856 2021-10-07 09:55:06+01:00   46.0
# 1147857 2021-10-07 09:55:07+01:00   46.0
# 1147441 2021-10-07 09:49:34+01:00   46.0
# 1147440 2021-10-07 09:49:33+01:00   46.0
# 1147439 2021-10-07 09:49:32+01:00   46.0
# 1147438 2021-10-07 09:49:32+01:00   46.0
# 1147152 2021-10-07 09:45:43+01:00   46.0
# 1149669 2021-10-07 10:19:16+01:00   45.0
# 1149668 2021-10-07 10:19:16+01:00   45.0
# 1149667 2021-10-07 10:19:15+01:00   45.0
# 1149671 2021-10-07 10:19:18+01:00   45.0
# 1148319 2021-10-07 10:01:16+01:00   45.0
# 959282  2021-10-05 11:48:21+01:00   45.0
# 1149193 2021-10-07 10:12:55+01:00   45.0
# 1147652 2021-10-07 09:52:23+01:00   45.0
# 1147660 2021-10-07 09:52:29+01:00   45.0
# 1147661 2021-10-07 09:52:30+01:00   45.0
# 1147662 2021-10-07 09:52:31+01:00   45.0
# 1149200 2021-10-07 10:13:01+01:00   45.0
# 1149199 2021-10-07 10:13:00+01:00   45.0
# 1149198 2021-10-07 10:12:59+01:00   45.0
# 1149197 2021-10-07 10:12:59+01:00   45.0
# 959281  2021-10-05 11:48:20+01:00   45.0
# 1149195 2021-10-07 10:12:57+01:00   45.0
# 1149194 2021-10-07 10:12:56+01:00   45.0
# 1149196 2021-10-07 10:12:58+01:00   45.0
# 959279  2021-10-05 11:48:19+01:00   45.0
# 959256  2021-10-05 11:48:00+01:00   45.0
# 959280  2021-10-05 11:48:20+01:00   45.0
# 1148314 2021-10-07 10:01:12+01:00   45.0
# 959278  2021-10-05 11:48:18+01:00   45.0
# 959257  2021-10-05 11:48:01+01:00   45.0
# 1147663 2021-10-07 09:52:32+01:00   45.0
# 1148318 2021-10-07 10:01:16+01:00   45.0
# 1148317 2021-10-07 10:01:15+01:00   45.0
# 1148316 2021-10-07 10:01:14+01:00   45.0
# 1148315 2021-10-07 10:01:13+01:00   45.0
# 1147659 2021-10-07 09:52:28+01:00   44.0
# 1147658 2021-10-07 09:52:28+01:00   44.0
# 1147655 2021-10-07 09:52:25+01:00   44.0
# 1147654 2021-10-07 09:52:24+01:00   44.0
# 1147653 2021-10-07 09:52:23+01:00   44.0
# 1149670 2021-10-07 10:19:17+01:00   44.0
# 1147657 2021-10-07 09:52:27+01:00   43.0
# 1147656 2021-10-07 09:52:26+01:00   43.0

# %%
start = dt.datetime(2022,8,20,18,7,59)
finish = dt.datetime(2022,8,20,19,47,59)

# %%
start = dt.datetime(2021,10,7, 9,25,26)
finish = dt.datetime(2021,10,7, 10,2,26)

# %%
hr.startDate = hr.startDate.dt.tz_localize(None)
# Out:
# /Users/tinym/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
hr.loc[(hr.startDate >= np.datetime64(start)) & (hr.startDate <= np.datetime64(finish))]
# Out:
#               type                     sourceName sourceVersion  \
# 1145631  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1145632  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1145633  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1145634  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1145635  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# ...            ...                            ...           ...
# 1148402  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1148403  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1148404  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1148405  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
# 1148406  HeartRate  Panagiotis Syrgkanis’s iPhone        14.7.1
#
#                                                     device       unit  \
# 1145631  <<HKDevice: 0x281588820>, name:WHOOP 3A097270,...  count/min
# 1145632  <<HKDevice: 0x281588820>, name:WHOOP 3A097270,...  count/min
# 1145633  <<HKDevice: 0x281588820>, name:WHOOP 3A097270,...  count/min
# 1145634  <<HKDevice: 0x281588820>, name:WHOOP 3A097270,...  count/min
# 1145635  <<HKDevice: 0x281588820>, name:WHOOP 3A097270,...  count/min
# ...                                                    ...        ...
# 1148402  <<HKDevice: 0x28158bd40>, name:WHOOP 3A097270,...  count/min
# 1148403  <<HKDevice: 0x28158bd40>, name:WHOOP 3A097270,...  count/min
# 1148404  <<HKDevice: 0x28158bd40>, name:WHOOP 3A097270,...  count/min
# 1148405  <<HKDevice: 0x28158bd40>, name:WHOOP 3A097270,...  count/min
# 1148406  <<HKDevice: 0x28158bd40>, name:WHOOP 3A097270,...  count/min
#
#                      creationDate           startDate  \
# 1145631 2021-10-07 09:25:27+01:00 2021-10-07 09:25:26
# 1145632 2021-10-07 09:25:27+01:00 2021-10-07 09:25:27
# 1145633 2021-10-07 09:25:29+01:00 2021-10-07 09:25:28
# 1145634 2021-10-07 09:25:29+01:00 2021-10-07 09:25:28
# 1145635 2021-10-07 09:25:30+01:00 2021-10-07 09:25:29
# ...                           ...                 ...
# 1148402 2021-10-07 10:02:24+01:00 2021-10-07 10:02:23
# 1148403 2021-10-07 10:02:24+01:00 2021-10-07 10:02:23
# 1148404 2021-10-07 10:02:25+01:00 2021-10-07 10:02:24
# 1148405 2021-10-07 10:02:25+01:00 2021-10-07 10:02:25
# 1148406 2021-10-07 10:02:27+01:00 2021-10-07 10:02:26
#
#                           endDate  value
# 1145631 2021-10-07 09:25:26+01:00   52.0
# 1145632 2021-10-07 09:25:27+01:00   52.0
# 1145633 2021-10-07 09:25:28+01:00   52.0
# 1145634 2021-10-07 09:25:28+01:00   52.0
# 1145635 2021-10-07 09:25:29+01:00   52.0
# ...                           ...    ...
# 1148402 2021-10-07 10:02:23+01:00   58.0
# 1148403 2021-10-07 10:02:23+01:00   58.0
# 1148404 2021-10-07 10:02:24+01:00   58.0
# 1148405 2021-10-07 10:02:25+01:00   58.0
# 1148406 2021-10-07 10:02:26+01:00   57.0
#
# [2776 rows x 9 columns]

# %%
hr.loc[(hr.startDate >= np.datetime64(start)) & (hr.startDate <= np.datetime64(finish))].value.plot()
# Out:
# <AxesSubplot:>

# %%
steps = data.loc[data.type == 'StepCount']

# %%
steps.head()
# Out:
#               type                     sourceName sourceVersion  \
# 1960500  StepCount  Panagiotis Syrgkanis’s iPhone        10.0.2
# 1960501  StepCount  Panagiotis Syrgkanis’s iPhone        10.0.2
# 1960502  StepCount  Panagiotis Syrgkanis’s iPhone        10.0.2
# 1960503  StepCount  Panagiotis Syrgkanis’s iPhone        10.0.2
# 1960504  StepCount  Panagiotis Syrgkanis’s iPhone        10.0.2
#
#                                                     device   unit  \
# 1960500  <<HKDevice: 0x2815ee350>, name:iPhone, manufac...  count
# 1960501  <<HKDevice: 0x2815ee350>, name:iPhone, manufac...  count
# 1960502  <<HKDevice: 0x2815ee350>, name:iPhone, manufac...  count
# 1960503  <<HKDevice: 0x2815ee350>, name:iPhone, manufac...  count
# 1960504  <<HKDevice: 0x2815ee350>, name:iPhone, manufac...  count
#
#                      creationDate                 startDate  \
# 1960500 2016-11-10 03:07:35+01:00 2016-11-10 02:28:43+01:00
# 1960501 2016-11-10 07:07:23+01:00 2016-11-10 06:34:20+01:00
# 1960502 2016-11-10 07:07:23+01:00 2016-11-10 06:41:21+01:00
# 1960503 2016-11-10 07:07:23+01:00 2016-11-10 06:50:20+01:00
# 1960504 2016-11-10 08:05:01+01:00 2016-11-10 07:00:18+01:00
#
#                           endDate  value
# 1960500 2016-11-10 02:37:22+01:00   90.0
# 1960501 2016-11-10 06:40:58+01:00    8.0
# 1960502 2016-11-10 06:50:20+01:00  136.0
# 1960503 2016-11-10 07:00:18+01:00  120.0
# 1960504 2016-11-10 07:10:16+01:00  221.0

# %%
data.sourceName.unique()
# Out:
# array(['FitTrack', 'Lifesum', 'JEFIT', 'Panagiotis Syrgkanis’s iPhone',
#        'Health', 'StrongLifts', 'iPhone', 'WHOOP', 'Freeletics',
#        'Mealime', 'Clock', 'Pillow', 'Flow', 'FitMind'], dtype=object)

# %% [markdown]
# ***
# ### Processing Steps

# %%
steps.creationDate = steps.creationDate.dt.date
# Out:
# /Users/tinym/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
steps.head()
# Out:
#               type                     sourceName sourceVersion  \
# 1960500  StepCount  Panagiotis Syrgkanis’s iPhone        10.0.2
# 1960501  StepCount  Panagiotis Syrgkanis’s iPhone        10.0.2
# 1960502  StepCount  Panagiotis Syrgkanis’s iPhone        10.0.2
# 1960503  StepCount  Panagiotis Syrgkanis’s iPhone        10.0.2
# 1960504  StepCount  Panagiotis Syrgkanis’s iPhone        10.0.2
#
#                                                     device   unit  \
# 1960500  <<HKDevice: 0x2815ee350>, name:iPhone, manufac...  count
# 1960501  <<HKDevice: 0x2815ee350>, name:iPhone, manufac...  count
# 1960502  <<HKDevice: 0x2815ee350>, name:iPhone, manufac...  count
# 1960503  <<HKDevice: 0x2815ee350>, name:iPhone, manufac...  count
# 1960504  <<HKDevice: 0x2815ee350>, name:iPhone, manufac...  count
#
#         creationDate                 startDate                   endDate  \
# 1960500   2016-11-10 2016-11-10 02:28:43+01:00 2016-11-10 02:37:22+01:00
# 1960501   2016-11-10 2016-11-10 06:34:20+01:00 2016-11-10 06:40:58+01:00
# 1960502   2016-11-10 2016-11-10 06:41:21+01:00 2016-11-10 06:50:20+01:00
# 1960503   2016-11-10 2016-11-10 06:50:20+01:00 2016-11-10 07:00:18+01:00
# 1960504   2016-11-10 2016-11-10 07:00:18+01:00 2016-11-10 07:10:16+01:00
#
#          value
# 1960500   90.0
# 1960501    8.0
# 1960502  136.0
# 1960503  120.0
# 1960504  221.0

# %%
stepsByDate = steps[['creationDate', 'value']].groupby('creationDate').sum()

# %%
stepsByDate.head()
# Out:
#                value
# creationDate
# 2016-11-10    5423.0
# 2016-11-11    8890.0
# 2016-11-12    6909.0
# 2016-11-13     577.0
# 2016-11-14    4366.0

# %%
type(stepsByDate)
# Out:
# pandas.core.frame.DataFrame

# %%
stepsByDate.plot();

# %% [markdown]
# ***
# ### Processing physio

# %%
physio["Date"] = pd.to_datetime(physio['Wake onset']).dt.date

# %%
physio.head()
# Out:
#       Cycle start time       Cycle end time Cycle timezone  Recovery score %  \
# 0  2022-11-28 01:03:57                  NaN      UTC+01:00              65.0
# 1  2022-11-27 03:18:18  2022-11-28 01:03:57      UTC+01:00              36.0
# 2  2022-11-26 03:51:55  2022-11-27 03:18:18      UTC+01:00              42.0
# 3  2022-11-25 03:24:54  2022-11-26 03:51:55      UTC+01:00              45.0
# 4  2022-11-24 03:17:20  2022-11-25 03:24:54      UTC+01:00              53.0
#
#    Resting heart rate (bpm)  Heart rate variability (ms)  Skin temp (celsius)  \
# 0                      61.0                         56.0                33.20
# 1                      65.0                         47.0                33.74
# 2                      61.0                         50.0                33.60
# 3                      58.0                         52.0                33.90
# 4                      59.0                         56.0                32.10
#
#    Blood oxygen %  Day Strain  Energy burned (cal)  ...  \
# 0           97.67         NaN                  NaN  ...
# 1           95.24         5.0               1740.0  ...
# 2           97.17        13.5               2651.0  ...
# 3           97.07        14.8               2984.0  ...
# 4           98.25         8.2               2121.0  ...
#
#    Asleep duration (min)  In bed duration (min) Light sleep duration (min)  \
# 0                  402.0                  427.0                      219.0
# 1                  413.0                  447.0                      218.0
# 2                  426.0                  464.0                      187.0
# 3                  435.0                  512.0                      200.0
# 4                  470.0                  522.0                      244.0
#
#   Deep (SWS) duration (min)  REM duration (min)  Awake duration (min)  \
# 0                      90.0                93.0                  25.0
# 1                      88.0               107.0                  34.0
# 2                     109.0               130.0                  38.0
# 3                     107.0               128.0                  77.0
# 4                     111.0               115.0                  52.0
#
#    Sleep need (min)  Sleep debt (min)  Sleep efficiency %        Date
# 0             528.0              56.0                96.0  2022-11-28
# 1             543.0              46.0                92.0  2022-11-27
# 2             535.0              30.0                92.0  2022-11-26
# 3             500.0              23.0                85.0  2022-11-25
# 4             523.0              51.0                90.0  2022-11-24
#
# [5 rows x 26 columns]

# %%
physio.dtypes
# Out:
# Cycle start time                object
# Cycle end time                  object
# Cycle timezone                  object
# Recovery score %               float64
# Resting heart rate (bpm)       float64
# Heart rate variability (ms)    float64
# Skin temp (celsius)            float64
# Blood oxygen %                 float64
# Day Strain                     float64
# Energy burned (cal)            float64
# Max HR (bpm)                   float64
# Average HR (bpm)               float64
# Sleep onset                     object
# Wake onset                      object
# Sleep performance %            float64
# Respiratory rate (rpm)         float64
# Asleep duration (min)          float64
# In bed duration (min)          float64
# Light sleep duration (min)     float64
# Deep (SWS) duration (min)      float64
# REM duration (min)             float64
# Awake duration (min)           float64
# Sleep need (min)               float64
# Sleep debt (min)               float64
# Sleep efficiency %             float64
# Date                            object
# dtype: object

# %% [markdown]
# ***
# ### Processing workouts

# %%
workout["Date"] = pd.to_datetime(workout['Cycle start time']).dt.date

# %%
workout.head()
# Out:
#       Cycle start time       Cycle end time Cycle timezone  \
# 0  2022-11-25 03:24:54  2022-11-26 03:51:55      UTC+01:00
# 1  2022-11-10 00:48:31  2022-11-10 23:39:33      UTC+01:00
# 2  2022-11-08 23:48:24  2022-11-10 00:48:31      UTC+01:00
# 3  2022-11-05 03:03:31  2022-11-06 00:38:48      UTC+01:00
# 4  2022-10-29 00:19:26  2022-10-30 01:33:11      UTC+02:00
#
#     Workout start time     Workout end time  Duration (min)  \
# 0  2022-11-26 01:33:32  2022-11-26 02:02:47              29
# 1  2022-11-10 16:31:49  2022-11-10 17:20:04              48
# 2  2022-11-09 16:00:00  2022-11-09 17:00:00              60
# 3  2022-11-05 14:20:53  2022-11-05 15:35:49              74
# 4  2022-10-29 19:58:53  2022-10-29 20:50:06              51
#
#         Activity name  Activity Strain  Energy burned (cal)  Max HR (bpm)  \
# 0            Activity              8.4                284.0         159.0
# 1  Functional Fitness              8.3                335.0         172.0
# 2  Functional Fitness              9.7                431.0         188.0
# 3       Weightlifting             12.2                674.0         169.0
# 4             Running             11.2                475.0         191.0
#
#    ...  HR Zone 1 %  HR Zone 2 %  HR Zone 3 %  HR Zone 4 %  HR Zone 5 %  \
# 0  ...          0.0          1.0         35.0         62.0          0.0
# 1  ...          0.0         16.0         60.0         18.0          4.0
# 2  ...          0.0         22.0         49.0         20.0          5.0
# 3  ...          0.0          3.0         40.0         52.0          2.0
# 4  ...          0.0          3.0         41.0         31.0         20.0
#
#    GPS enabled  Distance (meters)  Altitude gain (meters)  \
# 0        False                NaN                     NaN
# 1        False                NaN                     NaN
# 2        False                NaN                     NaN
# 3        False                NaN                     NaN
# 4        False                NaN                     NaN
#
#    Altitude change (meters)        Date
# 0                       NaN  2022-11-25
# 1                       NaN  2022-11-10
# 2                       NaN  2022-11-08
# 3                       NaN  2022-11-05
# 4                       NaN  2022-10-29
#
# [5 rows x 21 columns]

# %%
workout.drop(['Cycle start time', 'Cycle end time', 'Cycle timezone', 'Workout start time', 'Workout end time', 
                'Distance (meters)', 'Altitude gain (meters)', 'Altitude change (meters)', 'GPS enabled'], inplace=True, axis=1)

# %%
workout.dtypes
# Out:
# Duration (min)           int64
# Activity name           object
# Activity Strain        float64
# Energy burned (cal)    float64
# Max HR (bpm)           float64
# Average HR (bpm)       float64
# HR Zone 1 %            float64
# HR Zone 2 %            float64
# HR Zone 3 %            float64
# HR Zone 4 %            float64
# HR Zone 5 %            float64
# Date                    object
# dtype: object

# %%
workout.head()
# Out:
#    Duration (min)       Activity name  Activity Strain  Energy burned (cal)  \
# 0              29            Activity              8.4                284.0
# 1              48  Functional Fitness              8.3                335.0
# 2              60  Functional Fitness              9.7                431.0
# 3              74       Weightlifting             12.2                674.0
# 4              51             Running             11.2                475.0
#
#    Max HR (bpm)  Average HR (bpm)  HR Zone 1 %  HR Zone 2 %  HR Zone 3 %  \
# 0         159.0             140.0          0.0          1.0         35.0
# 1         172.0             127.0          0.0         16.0         60.0
# 2         188.0             128.0          0.0         22.0         49.0
# 3         169.0             137.0          0.0          3.0         40.0
# 4         191.0             138.0          0.0          3.0         41.0
#
#    HR Zone 4 %  HR Zone 5 %        Date
# 0         62.0          0.0  2022-11-25
# 1         18.0          4.0  2022-11-10
# 2         20.0          5.0  2022-11-08
# 3         52.0          2.0  2022-11-05
# 4         31.0         20.0  2022-10-29

# %% [markdown]
# ***
# ### Processing Sleep

# %%
sleep["Date"] = pd.to_datetime(sleep['Cycle start time']).dt.date

# %%
sleep.head()
# Out:
#       Cycle start time       Cycle end time Cycle timezone  \
# 0  2022-11-28 01:03:57                  NaN      UTC+01:00
# 1  2022-11-27 03:18:18  2022-11-28 01:03:57      UTC+01:00
# 2  2022-11-26 03:51:55  2022-11-27 03:18:18      UTC+01:00
# 3  2022-11-25 03:24:54  2022-11-26 03:51:55      UTC+01:00
# 4  2022-11-24 03:17:20  2022-11-25 03:24:54      UTC+01:00
#
#            Sleep onset           Wake onset  Sleep performance %  \
# 0  2022-11-28 01:03:57  2022-11-28 08:11:16                 76.0
# 1  2022-11-27 03:18:18  2022-11-27 10:52:02                 76.0
# 2  2022-11-26 03:51:55  2022-11-26 11:36:43                 80.0
# 3  2022-11-25 03:24:54  2022-11-25 11:58:44                 87.0
# 4  2022-11-24 03:17:20  2022-11-24 11:59:53                 90.0
#
#    Respiratory rate (rpm)  Asleep duration (min)  In bed duration (min)  \
# 0                    13.2                  402.0                  427.0
# 1                    13.4                  413.0                  447.0
# 2                    13.5                  426.0                  464.0
# 3                    13.0                  435.0                  512.0
# 4                    13.2                  470.0                  522.0
#
#    Light sleep duration (min)  Deep (SWS) duration (min)  REM duration (min)  \
# 0                       219.0                       90.0                93.0
# 1                       218.0                       88.0               107.0
# 2                       187.0                      109.0               130.0
# 3                       200.0                      107.0               128.0
# 4                       244.0                      111.0               115.0
#
#    Awake duration (min)  Sleep need (min)  Sleep debt (min)  \
# 0                  25.0             528.0              56.0
# 1                  34.0             543.0              46.0
# 2                  38.0             535.0              30.0
# 3                  77.0             500.0              23.0
# 4                  52.0             523.0              51.0
#
#    Sleep efficiency %    Nap        Date
# 0                96.0  False  2022-11-28
# 1                92.0  False  2022-11-27
# 2                92.0  False  2022-11-26
# 3                85.0  False  2022-11-25
# 4                90.0  False  2022-11-24

# %%
sleep['Sleep onset'] = pd.to_datetime(sleep['Sleep onset']) 
sleep['Wake onset'] = pd.to_datetime(sleep['Wake onset'])

# %%
sleep['Hour sleep'] = sleep['Sleep onset'].dt.hour
sleep['Hour wake'] = sleep['Wake onset'].dt.hour

# %%
sleep.drop(['Cycle start time', 'Cycle end time', 'Cycle timezone', 'Sleep onset', 'Wake onset'], inplace=True, axis=1)

# %%
sleep.dtypes
# Out:
# Sleep performance %           float64
# Respiratory rate (rpm)        float64
# Asleep duration (min)         float64
# In bed duration (min)         float64
# Light sleep duration (min)    float64
# Deep (SWS) duration (min)     float64
# REM duration (min)            float64
# Awake duration (min)          float64
# Sleep need (min)              float64
# Sleep debt (min)              float64
# Sleep efficiency %            float64
# Nap                              bool
# Date                           object
# Hour sleep                      int64
# Hour wake                       int64
# dtype: object

# %%
sleep.head()
# Out:
#    Sleep performance %  Respiratory rate (rpm)  Asleep duration (min)  \
# 0                 76.0                    13.2                  402.0
# 1                 76.0                    13.4                  413.0
# 2                 80.0                    13.5                  426.0
# 3                 87.0                    13.0                  435.0
# 4                 90.0                    13.2                  470.0
#
#    In bed duration (min)  Light sleep duration (min)  \
# 0                  427.0                       219.0
# 1                  447.0                       218.0
# 2                  464.0                       187.0
# 3                  512.0                       200.0
# 4                  522.0                       244.0
#
#    Deep (SWS) duration (min)  REM duration (min)  Awake duration (min)  \
# 0                       90.0                93.0                  25.0
# 1                       88.0               107.0                  34.0
# 2                      109.0               130.0                  38.0
# 3                      107.0               128.0                  77.0
# 4                      111.0               115.0                  52.0
#
#    Sleep need (min)  Sleep debt (min)  Sleep efficiency %    Nap        Date  \
# 0             528.0              56.0                96.0  False  2022-11-28
# 1             543.0              46.0                92.0  False  2022-11-27
# 2             535.0              30.0                92.0  False  2022-11-26
# 3             500.0              23.0                85.0  False  2022-11-25
# 4             523.0              51.0                90.0  False  2022-11-24
#
#    Hour sleep  Hour wake
# 0           1          8
# 1           3         10
# 2           3         11
# 3           3         11
# 4           3         11

# %% [markdown]
# ***
# ### PyMySQL & SQLalchemy

# %%
sleep.head()
# Out:
#    Sleep performance %  Respiratory rate (rpm)  Asleep duration (min)  \
# 0                 76.0                    13.2                  402.0
# 1                 76.0                    13.4                  413.0
# 2                 80.0                    13.5                  426.0
# 3                 87.0                    13.0                  435.0
# 4                 90.0                    13.2                  470.0
#
#    In bed duration (min)  Light sleep duration (min)  \
# 0                  427.0                       219.0
# 1                  447.0                       218.0
# 2                  464.0                       187.0
# 3                  512.0                       200.0
# 4                  522.0                       244.0
#
#    Deep (SWS) duration (min)  REM duration (min)  Awake duration (min)  \
# 0                       90.0                93.0                  25.0
# 1                       88.0               107.0                  34.0
# 2                      109.0               130.0                  38.0
# 3                      107.0               128.0                  77.0
# 4                      111.0               115.0                  52.0
#
#    Sleep need (min)  Sleep debt (min)  Sleep efficiency %    Nap        Date  \
# 0             528.0              56.0                96.0  False  2022-11-28
# 1             543.0              46.0                92.0  False  2022-11-27
# 2             535.0              30.0                92.0  False  2022-11-26
# 3             500.0              23.0                85.0  False  2022-11-25
# 4             523.0              51.0                90.0  False  2022-11-24
#
#    Hour sleep  Hour wake
# 0           1          8
# 1           3         10
# 2           3         11
# 3           3         11
# 4           3         11

# %%
sqlphysio = physio

# %%
for col in sleep.columns:
    try:
        if col != 'Date':
            sqlphysio = sqlphysio.drop(col, axis=1)
    except:
        print(col, "col not in physio")
# Out:
# Nap col not in physio
# Hour sleep col not in physio
# Hour wake col not in physio

# %%
sqlphysio.drop(['Sleep onset', 'Wake onset'], axis=1, inplace=True)

# %%
sqlphysio.drop(['Cycle start time', 'Cycle end time', 'Cycle timezone'], axis=1, inplace=True)

# %%
sqlphysio.head()
# Out:
#    Recovery score %  Resting heart rate (bpm)  Heart rate variability (ms)  \
# 0              65.0                      61.0                         56.0
# 1              36.0                      65.0                         47.0
# 2              42.0                      61.0                         50.0
# 3              45.0                      58.0                         52.0
# 4              53.0                      59.0                         56.0
#
#    Skin temp (celsius)  Blood oxygen %  Day Strain  Energy burned (cal)  \
# 0                33.20           97.67         NaN                  NaN
# 1                33.74           95.24         5.0               1740.0
# 2                33.60           97.17        13.5               2651.0
# 3                33.90           97.07        14.8               2984.0
# 4                32.10           98.25         8.2               2121.0
#
#    Max HR (bpm)  Average HR (bpm)        Date
# 0           NaN               NaN  2022-11-28
# 1         126.0              76.0  2022-11-27
# 2         159.0              84.0  2022-11-26
# 3         159.0              83.0  2022-11-25
# 4         154.0              79.0  2022-11-24

# %%
workout.head()
# Out:
#    Duration (min)       Activity name  Activity Strain  Energy burned (cal)  \
# 0              29            Activity              8.4                284.0
# 1              48  Functional Fitness              8.3                335.0
# 2              60  Functional Fitness              9.7                431.0
# 3              74       Weightlifting             12.2                674.0
# 4              51             Running             11.2                475.0
#
#    Max HR (bpm)  Average HR (bpm)  HR Zone 1 %  HR Zone 2 %  HR Zone 3 %  \
# 0         159.0             140.0          0.0          1.0         35.0
# 1         172.0             127.0          0.0         16.0         60.0
# 2         188.0             128.0          0.0         22.0         49.0
# 3         169.0             137.0          0.0          3.0         40.0
# 4         191.0             138.0          0.0          3.0         41.0
#
#    HR Zone 4 %  HR Zone 5 %        Date
# 0         62.0          0.0  2022-11-25
# 1         18.0          4.0  2022-11-10
# 2         20.0          5.0  2022-11-08
# 3         52.0          2.0  2022-11-05
# 4         31.0         20.0  2022-10-29

# %%
stepsByDate.reset_index(inplace=True)

# %%
stepsByDate.head()
# Out:
#   creationDate   value
# 0   2016-11-10  5423.0
# 1   2016-11-11  8890.0
# 2   2016-11-12  6909.0
# 3   2016-11-13   577.0
# 4   2016-11-14  4366.0

# %%
sqlphysio.head()
# Out:
#    Recovery score %  Resting heart rate (bpm)  Heart rate variability (ms)  \
# 0              65.0                      61.0                         56.0
# 1              36.0                      65.0                         47.0
# 2              42.0                      61.0                         50.0
# 3              45.0                      58.0                         52.0
# 4              53.0                      59.0                         56.0
#
#    Skin temp (celsius)  Blood oxygen %  Day Strain  Energy burned (cal)  \
# 0                33.20           97.67         NaN                  NaN
# 1                33.74           95.24         5.0               1740.0
# 2                33.60           97.17        13.5               2651.0
# 3                33.90           97.07        14.8               2984.0
# 4                32.10           98.25         8.2               2121.0
#
#    Max HR (bpm)  Average HR (bpm)        Date
# 0           NaN               NaN  2022-11-28
# 1         126.0              76.0  2022-11-27
# 2         159.0              84.0  2022-11-26
# 3         159.0              83.0  2022-11-25
# 4         154.0              79.0  2022-11-24

# %%
from sqlalchemy import create_engine

user = 'root'
host = '127.0.0.1'
password = '12345'
port = 3306
database = 'whoop'

my_conn = create_engine("mysql+pymysql://{0}:{1}@{2}:{3}/{4}".format(
            user, password, host, port, database
        ))
        
db_conn = my_conn.connect()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3211         try:
# -> 3212             return fn()
#    3213         except dialect.dbapi.Error as e:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in connect(self)
#     306         """
# --> 307         return _ConnectionFairy._checkout(self)
#     308
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     766         if not fairy:
# --> 767             fairy = _ConnectionRecord.checkout(pool)
#     768
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     424     def checkout(cls, pool):
# --> 425         rec = pool._do_get()
#     426         try:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     145                 with util.safe_reraise():
# --> 146                     self._dec_overflow()
#     147         else:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     206         try:
# --> 207             raise exception
#     208         finally:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     142             try:
# --> 143                 return self._create_connection()
#     144             except:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     252
# --> 253         return _ConnectionRecord(self)
#     254
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     367         if connect:
# --> 368             self.__connect()
#     369         self.finalize_callback = deque()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in __connect(self)
#     610             with util.safe_reraise():
# --> 611                 pool.logger.debug("Error on connect(): %s", e)
#     612         else:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     206         try:
# --> 207             raise exception
#     208         finally:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in __connect(self)
#     604             self.starttime = time.time()
# --> 605             connection = pool._invoke_creator(self)
#     606             pool.logger.debug("Created new connection %r", connection)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/create.py in connect(connection_record)
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     583         # inherits the docstring from interfaces.Dialect.connect
# --> 584         return self.dbapi.connect(*cargs, **cparams)
#     585
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pymysql/connections.py in __init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     352         else:
# --> 353             self.connect()
#     354
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pymysql/connections.py in connect(self, sock)
#     632             self._get_server_information()
# --> 633             self._request_authentication()
#     634
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pymysql/connections.py in _request_authentication(self)
#     931             if self._auth_plugin_name == "caching_sha2_password":
# --> 932                 auth_packet = _auth.caching_sha2_password_auth(self, auth_packet)
#     933             elif self._auth_plugin_name == "sha256_password":
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pymysql/_auth.py in caching_sha2_password_auth(conn, pkt)
#     265     data = sha2_rsa_encrypt(conn.password, conn.salt, conn.server_public_key)
# --> 266     pkt = _roundtrip(conn, data)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pymysql/_auth.py in _roundtrip(conn, send_data)
#     119     conn.write_packet(send_data)
# --> 120     pkt = conn._read_packet()
#     121     pkt.check_error()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     724                 self._result.unbuffered_active = False
# --> 725             packet.raise_for_error()
#     726         return packet
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pymysql/protocol.py in raise_for_error(self)
#     220             print("errno =", errno)
# --> 221         err.raise_mysql_exception(self._data)
#     222
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     142         errorclass = InternalError if errno < 1000 else OperationalError
# --> 143     raise errorclass(errno, errval)
#
# OperationalError: (1045, "Access denied for user 'root'@'localhost' (using password: YES)")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# /var/folders/sk/rfg_lvqj5r5c204vs5zftlgw0000gn/T/ipykernel_62700/1299335029.py in <module>
#      11         ))
#      12
# ---> 13 db_conn = my_conn.connect()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in connect(self, close_with_result)
#    3164         """
#    3165
# -> 3166         return self._connection_cls(self, close_with_result=close_with_result)
#    3167
#    3168     @util.deprecated(
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events, _allow_revalidate)
#      94                 connection
#      95                 if connection is not None
# ---> 96                 else engine.raw_connection()
#      97             )
#      98
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in raw_connection(self, _connection)
#    3243
#    3244         """
# -> 3245         return self._wrap_pool_connect(self.pool.connect, _connection)
#    3246
#    3247
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3213         except dialect.dbapi.Error as e:
#    3214             if connection is None:
# -> 3215                 Connection._handle_dbapi_exception_noconnection(
#    3216                     e, dialect, self
#    3217                 )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2067             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2068         elif should_wrap:
# -> 2069             util.raise_(
#    2070                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2071             )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3210         dialect = self.dialect
#    3211         try:
# -> 3212             return fn()
#    3213         except dialect.dbapi.Error as e:
#    3214             if connection is None:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in connect(self)
#     305
#     306         """
# --> 307         return _ConnectionFairy._checkout(self)
#     308
#     309     def _return_conn(self, record):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     765     def _checkout(cls, pool, threadconns=None, fairy=None):
#     766         if not fairy:
# --> 767             fairy = _ConnectionRecord.checkout(pool)
#     768
#     769             fairy._pool = pool
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     423     @classmethod
#     424     def checkout(cls, pool):
# --> 425         rec = pool._do_get()
#     426         try:
#     427             dbapi_connection = rec.get_connection()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     144             except:
#     145                 with util.safe_reraise():
# --> 146                     self._dec_overflow()
#     147         else:
#     148             return self._do_get()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     141         if self._inc_overflow():
#     142             try:
# --> 143                 return self._create_connection()
#     144             except:
#     145                 with util.safe_reraise():
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     251         """Called by subclasses to create a new ConnectionRecord."""
#     252
# --> 253         return _ConnectionRecord(self)
#     254
#     255     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     366         self.__pool = pool
#     367         if connect:
# --> 368             self.__connect()
#     369         self.finalize_callback = deque()
#     370
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in __connect(self)
#     609         except Exception as e:
#     610             with util.safe_reraise():
# --> 611                 pool.logger.debug("Error on connect(): %s", e)
#     612         else:
#     613             # in SQLAlchemy 1.4 the first_connect event is not used by
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in __connect(self)
#     603         try:
#     604             self.starttime = time.time()
# --> 605             connection = pool._invoke_creator(self)
#     606             pool.logger.debug("Created new connection %r", connection)
#     607             self.connection = connection
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/create.py in connect(connection_record)
#     576                     if connection is not None:
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#     580         creator = pop_kwarg("creator", connect)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     582     def connect(self, *cargs, **cparams):
#     583         # inherits the docstring from interfaces.Dialect.connect
# --> 584         return self.dbapi.connect(*cargs, **cparams)
#     585
#     586     def create_connect_args(self, url):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pymysql/connections.py in __init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     351             self._sock = None
#     352         else:
# --> 353             self.connect()
#     354
#     355     def __enter__(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pymysql/connections.py in connect(self, sock)
#     631
#     632             self._get_server_information()
# --> 633             self._request_authentication()
#     634
#     635             if self.sql_mode is not None:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pymysql/connections.py in _request_authentication(self)
#     930             # https://dev.mysql.com/doc/internals/en/successful-authentication.html
#     931             if self._auth_plugin_name == "caching_sha2_password":
# --> 932                 auth_packet = _auth.caching_sha2_password_auth(self, auth_packet)
#     933             elif self._auth_plugin_name == "sha256_password":
#     934                 auth_packet = _auth.sha256_password_auth(self, auth_packet)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pymysql/_auth.py in caching_sha2_password_auth(conn, pkt)
#     264
#     265     data = sha2_rsa_encrypt(conn.password, conn.salt, conn.server_public_key)
# --> 266     pkt = _roundtrip(conn, data)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pymysql/_auth.py in _roundtrip(conn, send_data)
#     118 def _roundtrip(conn, send_data):
#     119     conn.write_packet(send_data)
# --> 120     pkt = conn._read_packet()
#     121     pkt.check_error()
#     122     return pkt
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     723             if self._result is not None and self._result.unbuffered_active is True:
#     724                 self._result.unbuffered_active = False
# --> 725             packet.raise_for_error()
#     726         return packet
#     727
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pymysql/protocol.py in raise_for_error(self)
#     219         if DEBUG:
#     220             print("errno =", errno)
# --> 221         err.raise_mysql_exception(self._data)
#     222
#     223     def dump(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     141     if errorclass is None:
#     142         errorclass = InternalError if errno < 1000 else OperationalError
# --> 143     raise errorclass(errno, errval)
#
# OperationalError: (pymysql.err.OperationalError) (1045, "Access denied for user 'root'@'localhost' (using password: YES)")
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %%
try:
    frame = workout.to_sql("workout", db_conn, if_exists='fail')
    frame = sleep.to_sql("sleep", db_conn, if_exists='fail')
    frame = sqlphysio.to_sql("physio", db_conn, if_exists='fail')
    frame = stepsByDate.to_sql("steps", db_conn, if_exists='fail')

except ValueError as vx:
    print(vx)

except Exception as ex:   
    print(ex)

else:
    print("Table %s created successfully."%"df");   

finally:
    db_conn.close()
# Out:
# Table 'workout' already exists.

# %% [markdown]
# ***
# ### Joining
# Fixing dates and joining on them

# %%
df = physio.merge(stepsByDate, left_on='Date', right_on='creationDate', how='left')

# %%
df.drop('creationDate', axis=1, inplace=True)

# %%
df.head()
# Out:
#       Cycle start time       Cycle end time Cycle timezone  Recovery score %  \
# 0  2022-11-28 01:03:57                  NaN      UTC+01:00              65.0
# 1  2022-11-27 03:18:18  2022-11-28 01:03:57      UTC+01:00              36.0
# 2  2022-11-26 03:51:55  2022-11-27 03:18:18      UTC+01:00              42.0
# 3  2022-11-25 03:24:54  2022-11-26 03:51:55      UTC+01:00              45.0
# 4  2022-11-24 03:17:20  2022-11-25 03:24:54      UTC+01:00              53.0
#
#    Resting heart rate (bpm)  Heart rate variability (ms)  Skin temp (celsius)  \
# 0                      61.0                         56.0                33.20
# 1                      65.0                         47.0                33.74
# 2                      61.0                         50.0                33.60
# 3                      58.0                         52.0                33.90
# 4                      59.0                         56.0                32.10
#
#    Blood oxygen %  Day Strain  Energy burned (cal)  ...  \
# 0           97.67         NaN                  NaN  ...
# 1           95.24         5.0               1740.0  ...
# 2           97.17        13.5               2651.0  ...
# 3           97.07        14.8               2984.0  ...
# 4           98.25         8.2               2121.0  ...
#
#    In bed duration (min)  Light sleep duration (min)  \
# 0                  427.0                       219.0
# 1                  447.0                       218.0
# 2                  464.0                       187.0
# 3                  512.0                       200.0
# 4                  522.0                       244.0
#
#   Deep (SWS) duration (min) REM duration (min)  Awake duration (min)  \
# 0                      90.0               93.0                  25.0
# 1                      88.0              107.0                  34.0
# 2                     109.0              130.0                  38.0
# 3                     107.0              128.0                  77.0
# 4                     111.0              115.0                  52.0
#
#    Sleep need (min)  Sleep debt (min)  Sleep efficiency %        Date    value
# 0             528.0              56.0                96.0  2022-11-28   2438.0
# 1             543.0              46.0                92.0  2022-11-27   3603.0
# 2             535.0              30.0                92.0  2022-11-26  12908.0
# 3             500.0              23.0                85.0  2022-11-25  10299.0
# 4             523.0              51.0                90.0  2022-11-24   5782.0
#
# [5 rows x 27 columns]

# %%
df.rename(columns = {'value':'Steps'}, inplace = True)

# %%
df.head()
# Out:
#       Cycle start time       Cycle end time Cycle timezone  Recovery score %  \
# 0  2022-11-28 01:03:57                  NaN      UTC+01:00              65.0
# 1  2022-11-27 03:18:18  2022-11-28 01:03:57      UTC+01:00              36.0
# 2  2022-11-26 03:51:55  2022-11-27 03:18:18      UTC+01:00              42.0
# 3  2022-11-25 03:24:54  2022-11-26 03:51:55      UTC+01:00              45.0
# 4  2022-11-24 03:17:20  2022-11-25 03:24:54      UTC+01:00              53.0
#
#    Resting heart rate (bpm)  Heart rate variability (ms)  Skin temp (celsius)  \
# 0                      61.0                         56.0                33.20
# 1                      65.0                         47.0                33.74
# 2                      61.0                         50.0                33.60
# 3                      58.0                         52.0                33.90
# 4                      59.0                         56.0                32.10
#
#    Blood oxygen %  Day Strain  Energy burned (cal)  ...  \
# 0           97.67         NaN                  NaN  ...
# 1           95.24         5.0               1740.0  ...
# 2           97.17        13.5               2651.0  ...
# 3           97.07        14.8               2984.0  ...
# 4           98.25         8.2               2121.0  ...
#
#    In bed duration (min)  Light sleep duration (min)  \
# 0                  427.0                       219.0
# 1                  447.0                       218.0
# 2                  464.0                       187.0
# 3                  512.0                       200.0
# 4                  522.0                       244.0
#
#   Deep (SWS) duration (min) REM duration (min)  Awake duration (min)  \
# 0                      90.0               93.0                  25.0
# 1                      88.0              107.0                  34.0
# 2                     109.0              130.0                  38.0
# 3                     107.0              128.0                  77.0
# 4                     111.0              115.0                  52.0
#
#    Sleep need (min)  Sleep debt (min)  Sleep efficiency %        Date    Steps
# 0             528.0              56.0                96.0  2022-11-28   2438.0
# 1             543.0              46.0                92.0  2022-11-27   3603.0
# 2             535.0              30.0                92.0  2022-11-26  12908.0
# 3             500.0              23.0                85.0  2022-11-25  10299.0
# 4             523.0              51.0                90.0  2022-11-24   5782.0
#
# [5 rows x 27 columns]

# %%
df.drop(['Cycle start time', 'Cycle end time'], inplace=True, axis=1)

# %%
df.columns
# Out:
# Index(['Cycle timezone', 'Recovery score %', 'Resting heart rate (bpm)',
#        'Heart rate variability (ms)', 'Skin temp (celsius)', 'Blood oxygen %',
#        'Day Strain', 'Energy burned (cal)', 'Max HR (bpm)', 'Average HR (bpm)',
#        'Sleep onset', 'Wake onset', 'Sleep performance %',
#        'Respiratory rate (rpm)', 'Asleep duration (min)',
#        'In bed duration (min)', 'Light sleep duration (min)',
#        'Deep (SWS) duration (min)', 'REM duration (min)',
#        'Awake duration (min)', 'Sleep need (min)', 'Sleep debt (min)',
#        'Sleep efficiency %', 'Date', 'Steps'],
#       dtype='object')

# %%
df = df[['Date', 'Resting heart rate (bpm)',
       'Heart rate variability (ms)', 'Skin temp (celsius)', 'Blood oxygen %',
       'Energy burned (cal)', 'Max HR (bpm)', 'Average HR (bpm)',
       'Sleep onset', 'Wake onset', 'Sleep performance %',
       'Respiratory rate (rpm)', 'Asleep duration (min)',
       'Light sleep duration (min)', 'Deep (SWS) duration (min)',
       'REM duration (min)', 'Awake duration (min)', 'Sleep need (min)',
       'Sleep debt (min)', 'Steps', 'Day Strain', 'Recovery score %']]

# %%
df.head()
# Out:
#          Date  Resting heart rate (bpm)  Heart rate variability (ms)  \
# 0  2022-11-28                      61.0                         56.0
# 1  2022-11-27                      65.0                         47.0
# 2  2022-11-26                      61.0                         50.0
# 3  2022-11-25                      58.0                         52.0
# 4  2022-11-24                      59.0                         56.0
#
#    Skin temp (celsius)  Blood oxygen %  Energy burned (cal)  Max HR (bpm)  \
# 0                33.20           97.67                  NaN           NaN
# 1                33.74           95.24               1740.0         126.0
# 2                33.60           97.17               2651.0         159.0
# 3                33.90           97.07               2984.0         159.0
# 4                32.10           98.25               2121.0         154.0
#
#    Average HR (bpm)          Sleep onset           Wake onset  ...  \
# 0               NaN  2022-11-28 01:03:57  2022-11-28 08:11:16  ...
# 1              76.0  2022-11-27 03:18:18  2022-11-27 10:52:02  ...
# 2              84.0  2022-11-26 03:51:55  2022-11-26 11:36:43  ...
# 3              83.0  2022-11-25 03:24:54  2022-11-25 11:58:44  ...
# 4              79.0  2022-11-24 03:17:20  2022-11-24 11:59:53  ...
#
#    Asleep duration (min)  Light sleep duration (min)  \
# 0                  402.0                       219.0
# 1                  413.0                       218.0
# 2                  426.0                       187.0
# 3                  435.0                       200.0
# 4                  470.0                       244.0
#
#    Deep (SWS) duration (min)  REM duration (min)  Awake duration (min)  \
# 0                       90.0                93.0                  25.0
# 1                       88.0               107.0                  34.0
# 2                      109.0               130.0                  38.0
# 3                      107.0               128.0                  77.0
# 4                      111.0               115.0                  52.0
#
#    Sleep need (min)  Sleep debt (min)    Steps  Day Strain  Recovery score %
# 0             528.0              56.0   2438.0         NaN              65.0
# 1             543.0              46.0   3603.0         5.0              36.0
# 2             535.0              30.0  12908.0        13.5              42.0
# 3             500.0              23.0  10299.0        14.8              45.0
# 4             523.0              51.0   5782.0         8.2              53.0
#
# [5 rows x 22 columns]

# %% [markdown]
# ***
# ### Correlations

# %%
del steps
del root
del record_list
del hr
del data
del tree

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def plot_cor(data):
	corr = data.corr()
	mask = np.triu(np.ones_like(corr))
	ax = sns.heatmap(
		corr, mask=mask,
		vmin=-1, vmax=1, center=0,
		cmap=sns.diverging_palette(20, 220, n=200),
		square=True
	)
	ax.set_xticklabels(
		ax.get_xticklabels(),
		rotation=45,
		horizontalalignment='right'
	);

# %%
plot_cor(df)

# %%
def drop_cor(df, trsh=0.9):
	# Create correlation matrix
	corr_matrix = df.corr().abs()
	
	# Select upper triangle of correlation matrix
	upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape),
								k=1).astype(bool))
	
	# Find features with correlation greater than 0.9
	to_drop = [column for column in upper.columns if any(upper[column] > trsh)]
	
	# Drop features 
	df.drop(to_drop, axis=1, inplace=True)

# %%
# drop_cor(df)

# %%
plot_cor(df)

# %% [markdown]
# ***
# ### Date Handling

# %%
dates = df["Date"].tolist()
dates
# Out:
# [datetime.date(2022, 11, 28),
#  datetime.date(2022, 11, 27),
#  datetime.date(2022, 11, 26),
#  datetime.date(2022, 11, 25),
#  datetime.date(2022, 11, 24),
#  datetime.date(2022, 11, 23),
#  datetime.date(2022, 11, 22),
#  datetime.date(2022, 11, 21),
#  datetime.date(2022, 11, 20),
#  datetime.date(2022, 11, 19),
#  datetime.date(2022, 11, 18),
#  datetime.date(2022, 11, 17),
#  datetime.date(2022, 11, 16),
#  datetime.date(2022, 11, 15),
#  datetime.date(2022, 11, 14),
#  datetime.date(2022, 11, 13),
#  datetime.date(2022, 11, 12),
#  datetime.date(2022, 11, 11),
#  datetime.date(2022, 11, 10),
#  datetime.date(2022, 11, 9),
#  datetime.date(2022, 11, 8),
#  datetime.date(2022, 11, 7),
#  datetime.date(2022, 11, 6),
#  datetime.date(2022, 11, 5),
#  datetime.date(2022, 11, 4),
#  datetime.date(2022, 11, 3),
#  datetime.date(2022, 11, 2),
#  datetime.date(2022, 11, 1),
#  datetime.date(2022, 10, 31),
#  datetime.date(2022, 10, 30),
#  datetime.date(2022, 10, 29),
#  datetime.date(2022, 10, 28),
#  datetime.date(2022, 10, 27),
#  datetime.date(2022, 10, 26),
#  datetime.date(2022, 10, 25),
#  datetime.date(2022, 10, 24),
#  datetime.date(2022, 10, 23),
#  datetime.date(2022, 10, 22),
#  datetime.date(2022, 10, 21),
#  datetime.date(2022, 10, 20),
#  datetime.date(2022, 10, 19),
#  datetime.date(2022, 10, 18),
#  datetime.date(2022, 10, 17),
#  datetime.date(2022, 10, 16),
#  datetime.date(2022, 10, 15),
#  datetime.date(2022, 10, 14),
#  datetime.date(2022, 10, 13),
#  datetime.date(2022, 10, 12),
#  datetime.date(2022, 10, 11),
#  datetime.date(2022, 10, 10),
#  datetime.date(2022, 10, 9),
#  datetime.date(2022, 10, 8),
#  datetime.date(2022, 10, 7),
#  datetime.date(2022, 10, 6),
#  datetime.date(2022, 10, 5),
#  datetime.date(2022, 10, 4),
#  datetime.date(2022, 10, 3),
#  datetime.date(2022, 10, 2),
#  datetime.date(2022, 10, 1),
#  datetime.date(2022, 9, 30),
#  datetime.date(2022, 9, 29),
#  datetime.date(2022, 9, 28),
#  datetime.date(2022, 9, 27),
#  datetime.date(2022, 9, 26),
#  datetime.date(2022, 9, 25),
#  datetime.date(2022, 9, 24),
#  datetime.date(2022, 9, 23),
#  datetime.date(2022, 9, 22),
#  datetime.date(2022, 9, 21),
#  datetime.date(2022, 9, 20),
#  datetime.date(2022, 9, 19),
#  datetime.date(2022, 9, 18),
#  datetime.date(2022, 9, 17),
#  datetime.date(2022, 9, 16),
#  datetime.date(2022, 9, 15),
#  datetime.date(2022, 9, 14),
#  datetime.date(2022, 9, 13),
#  datetime.date(2022, 9, 12),
#  datetime.date(2022, 9, 11),
#  datetime.date(2022, 9, 10),
#  datetime.date(2022, 9, 9),
#  datetime.date(2022, 9, 8),
#  datetime.date(2022, 9, 7),
#  datetime.date(2022, 9, 6),
#  datetime.date(2022, 9, 5),
#  datetime.date(2022, 9, 4),
#  datetime.date(2022, 9, 3),
#  datetime.date(2022, 9, 2),
#  datetime.date(2022, 9, 1),
#  datetime.date(2022, 8, 31),
#  datetime.date(2022, 8, 30),
#  datetime.date(2022, 8, 29),
#  datetime.date(2022, 8, 28),
#  datetime.date(2022, 8, 27),
#  datetime.date(2022, 8, 26),
#  datetime.date(2022, 8, 25),
#  datetime.date(2022, 8, 24),
#  datetime.date(2022, 8, 23),
#  datetime.date(2022, 8, 22),
#  datetime.date(2022, 8, 21),
#  datetime.date(2022, 8, 20),
#  datetime.date(2022, 8, 19),
#  datetime.date(2022, 8, 18),
#  datetime.date(2022, 8, 17),
#  datetime.date(2022, 8, 16),
#  datetime.date(2022, 8, 15),
#  datetime.date(2022, 8, 14),
#  datetime.date(2022, 8, 13),
#  datetime.date(2022, 8, 12),
#  datetime.date(2022, 8, 11),
#  datetime.date(2022, 8, 10),
#  datetime.date(2022, 8, 9),
#  datetime.date(2022, 8, 8),
#  datetime.date(2022, 8, 7),
#  datetime.date(2022, 8, 6),
#  datetime.date(2022, 8, 5),
#  datetime.date(2022, 8, 4),
#  datetime.date(2022, 8, 3),
#  datetime.date(2022, 8, 2),
#  datetime.date(2022, 8, 1),
#  datetime.date(2022, 7, 31),
#  datetime.date(2022, 7, 30),
#  datetime.date(2022, 7, 29),
#  datetime.date(2022, 7, 28),
#  datetime.date(2022, 7, 27),
#  datetime.date(2022, 7, 26),
#  datetime.date(2022, 7, 25),
#  datetime.date(2022, 7, 24),
#  datetime.date(2022, 7, 23),
#  datetime.date(2022, 7, 22),
#  datetime.date(2022, 7, 21),
#  datetime.date(2022, 7, 20),
#  datetime.date(2022, 7, 19),
#  datetime.date(2022, 7, 18),
#  datetime.date(2022, 7, 17),
#  datetime.date(2022, 7, 16),
#  datetime.date(2022, 7, 15),
#  datetime.date(2022, 7, 14),
#  datetime.date(2022, 7, 13),
#  datetime.date(2022, 7, 12),
#  datetime.date(2022, 7, 11),
#  datetime.date(2022, 7, 10),
#  datetime.date(2022, 7, 9),
#  datetime.date(2022, 7, 8),
#  datetime.date(2022, 7, 7),
#  datetime.date(2022, 7, 6),
#  datetime.date(2022, 7, 5),
#  datetime.date(2022, 7, 4),
#  datetime.date(2022, 7, 3),
#  datetime.date(2022, 7, 2),
#  datetime.date(2022, 7, 1),
#  datetime.date(2022, 6, 30),
#  datetime.date(2022, 6, 29),
#  datetime.date(2022, 6, 28),
#  datetime.date(2022, 6, 27),
#  datetime.date(2022, 6, 26),
#  datetime.date(2022, 6, 25),
#  datetime.date(2022, 6, 24),
#  datetime.date(2022, 6, 23),
#  datetime.date(2022, 6, 22),
#  datetime.date(2022, 6, 21),
#  datetime.date(2022, 6, 20),
#  datetime.date(2022, 6, 19),
#  datetime.date(2022, 6, 18),
#  datetime.date(2022, 6, 17),
#  datetime.date(2022, 6, 16),
#  datetime.date(2022, 6, 15),
#  datetime.date(2022, 6, 14),
#  datetime.date(2022, 6, 13),
#  datetime.date(2022, 6, 12),
#  datetime.date(2022, 6, 11),
#  datetime.date(2022, 6, 10),
#  datetime.date(2022, 6, 9),
#  datetime.date(2022, 6, 8),
#  datetime.date(2022, 6, 7),
#  datetime.date(2022, 6, 6),
#  datetime.date(2022, 6, 5),
#  datetime.date(2022, 6, 4),
#  datetime.date(2022, 6, 3),
#  datetime.date(2022, 6, 2),
#  datetime.date(2022, 6, 1),
#  datetime.date(2022, 5, 31),
#  datetime.date(2022, 5, 30),
#  datetime.date(2022, 5, 29),
#  datetime.date(2022, 5, 28),
#  datetime.date(2022, 5, 27),
#  datetime.date(2022, 5, 26),
#  datetime.date(2022, 5, 25),
#  datetime.date(2022, 5, 24),
#  datetime.date(2022, 5, 23),
#  datetime.date(2022, 5, 22),
#  datetime.date(2022, 5, 21),
#  datetime.date(2022, 5, 20),
#  datetime.date(2022, 5, 19),
#  datetime.date(2022, 5, 18),
#  datetime.date(2022, 5, 17),
#  datetime.date(2022, 5, 16),
#  datetime.date(2022, 5, 15),
#  datetime.date(2022, 5, 14),
#  datetime.date(2022, 5, 13),
#  datetime.date(2022, 5, 12),
#  datetime.date(2022, 5, 11),
#  datetime.date(2022, 5, 10),
#  datetime.date(2022, 5, 9),
#  datetime.date(2022, 5, 8),
#  datetime.date(2022, 5, 7),
#  datetime.date(2022, 5, 6),
#  datetime.date(2022, 5, 5),
#  datetime.date(2022, 5, 4),
#  datetime.date(2022, 5, 3),
#  datetime.date(2022, 5, 2),
#  datetime.date(2022, 5, 1),
#  datetime.date(2022, 4, 30),
#  datetime.date(2022, 4, 29),
#  datetime.date(2022, 4, 28),
#  datetime.date(2022, 4, 27),
#  datetime.date(2022, 4, 26),
#  datetime.date(2022, 4, 25),
#  datetime.date(2022, 4, 24),
#  datetime.date(2022, 4, 23),
#  datetime.date(2022, 4, 22),
#  datetime.date(2022, 4, 21),
#  datetime.date(2022, 4, 20),
#  datetime.date(2022, 4, 19),
#  datetime.date(2022, 4, 18),
#  datetime.date(2022, 4, 17),
#  datetime.date(2022, 4, 16),
#  datetime.date(2022, 4, 15),
#  NaT,
#  datetime.date(2022, 3, 23),
#  datetime.date(2022, 3, 22),
#  datetime.date(2022, 3, 21),
#  datetime.date(2022, 3, 20),
#  datetime.date(2022, 3, 19),
#  datetime.date(2022, 3, 18),
#  datetime.date(2022, 3, 17),
#  datetime.date(2022, 3, 16),
#  datetime.date(2022, 3, 15),
#  datetime.date(2022, 3, 14),
#  datetime.date(2022, 3, 13),
#  datetime.date(2022, 3, 12),
#  datetime.date(2022, 3, 11),
#  datetime.date(2022, 3, 10),
#  datetime.date(2022, 3, 9),
#  datetime.date(2022, 3, 8),
#  datetime.date(2022, 3, 7),
#  datetime.date(2022, 3, 6),
#  datetime.date(2022, 3, 5),
#  datetime.date(2022, 3, 4),
#  datetime.date(2022, 3, 3),
#  datetime.date(2022, 3, 2),
#  datetime.date(2022, 3, 1),
#  datetime.date(2022, 2, 28),
#  datetime.date(2022, 2, 27),
#  datetime.date(2022, 2, 26),
#  datetime.date(2022, 2, 25),
#  datetime.date(2022, 2, 24),
#  datetime.date(2022, 2, 23),
#  datetime.date(2022, 2, 22),
#  datetime.date(2022, 2, 21),
#  datetime.date(2022, 2, 20),
#  datetime.date(2022, 2, 19),
#  datetime.date(2022, 2, 18),
#  datetime.date(2022, 2, 17),
#  datetime.date(2022, 2, 16),
#  datetime.date(2022, 2, 15),
#  datetime.date(2022, 2, 14),
#  datetime.date(2022, 2, 13),
#  datetime.date(2022, 2, 12),
#  datetime.date(2022, 2, 11),
#  datetime.date(2022, 2, 10),
#  datetime.date(2022, 2, 9),
#  datetime.date(2022, 2, 8),
#  datetime.date(2022, 2, 7),
#  datetime.date(2022, 2, 6),
#  datetime.date(2022, 2, 5),
#  datetime.date(2022, 2, 4),
#  datetime.date(2022, 2, 3),
#  datetime.date(2022, 2, 2),
#  datetime.date(2022, 2, 1),
#  datetime.date(2022, 1, 31),
#  datetime.date(2022, 1, 30),
#  datetime.date(2022, 1, 29),
#  datetime.date(2022, 1, 28),
#  datetime.date(2022, 1, 27),
#  datetime.date(2022, 1, 26),
#  datetime.date(2022, 1, 25),
#  datetime.date(2022, 1, 24),
#  datetime.date(2022, 1, 23),
#  datetime.date(2022, 1, 22),
#  datetime.date(2022, 1, 16),
#  datetime.date(2022, 1, 15),
#  datetime.date(2022, 1, 14),
#  datetime.date(2022, 1, 13),
#  datetime.date(2022, 1, 12),
#  datetime.date(2022, 1, 11),
#  datetime.date(2022, 1, 10),
#  datetime.date(2022, 1, 9),
#  datetime.date(2022, 1, 8),
#  datetime.date(2022, 1, 7),
#  datetime.date(2022, 1, 6),
#  datetime.date(2022, 1, 5),
#  datetime.date(2022, 1, 4),
#  datetime.date(2022, 1, 3),
#  datetime.date(2022, 1, 2),
#  datetime.date(2022, 1, 1),
#  datetime.date(2021, 12, 31),
#  datetime.date(2021, 12, 30),
#  datetime.date(2021, 12, 29),
#  datetime.date(2021, 12, 28),
#  NaT,
#  datetime.date(2021, 12, 26),
#  datetime.date(2021, 12, 25),
#  datetime.date(2021, 12, 24),
#  datetime.date(2021, 12, 23),
#  datetime.date(2021, 12, 22),
#  datetime.date(2021, 12, 21),
#  datetime.date(2021, 12, 20),
#  datetime.date(2021, 12, 19),
#  datetime.date(2021, 12, 18),
#  datetime.date(2021, 12, 17),
#  datetime.date(2021, 12, 16),
#  datetime.date(2021, 12, 15),
#  datetime.date(2021, 12, 14),
#  datetime.date(2021, 12, 13),
#  datetime.date(2021, 12, 12),
#  datetime.date(2021, 12, 11),
#  datetime.date(2021, 12, 10),
#  datetime.date(2021, 12, 9),
#  datetime.date(2021, 12, 8),
#  datetime.date(2021, 12, 7),
#  datetime.date(2021, 12, 6),
#  datetime.date(2021, 12, 5),
#  datetime.date(2021, 12, 4),
#  datetime.date(2021, 12, 3),
#  datetime.date(2021, 12, 2),
#  datetime.date(2021, 12, 1),
#  datetime.date(2021, 11, 30),
#  datetime.date(2021, 11, 29),
#  datetime.date(2021, 11, 28),
#  datetime.date(2021, 11, 27),
#  datetime.date(2021, 11, 26),
#  datetime.date(2021, 11, 25),
#  datetime.date(2021, 11, 24),
#  datetime.date(2021, 11, 23),
#  datetime.date(2021, 11, 22),
#  datetime.date(2021, 11, 21),
#  datetime.date(2021, 11, 20),
#  datetime.date(2021, 11, 19),
#  datetime.date(2021, 11, 18),
#  datetime.date(2021, 11, 17),
#  datetime.date(2021, 11, 16),
#  datetime.date(2021, 11, 15),
#  datetime.date(2021, 11, 14),
#  datetime.date(2021, 11, 13),
#  datetime.date(2021, 11, 12),
#  datetime.date(2021, 11, 11),
#  datetime.date(2021, 11, 10),
#  datetime.date(2021, 11, 9),
#  datetime.date(2021, 11, 8),
#  datetime.date(2021, 11, 7),
#  datetime.date(2021, 11, 6),
#  datetime.date(2021, 11, 5),
#  datetime.date(2021, 11, 4),
#  datetime.date(2021, 11, 3),
#  datetime.date(2021, 11, 2),
#  datetime.date(2021, 11, 1),
#  datetime.date(2021, 10, 31),
#  datetime.date(2021, 10, 30),
#  datetime.date(2021, 10, 29),
#  datetime.date(2021, 10, 28),
#  datetime.date(2021, 10, 27),
#  datetime.date(2021, 10, 26),
#  datetime.date(2021, 10, 25),
#  datetime.date(2021, 10, 24),
#  datetime.date(2021, 10, 23),
#  datetime.date(2021, 10, 22),
#  datetime.date(2021, 10, 21),
#  datetime.date(2021, 10, 20),
#  datetime.date(2021, 10, 19),
#  datetime.date(2021, 10, 18),
#  datetime.date(2021, 10, 17),
#  datetime.date(2021, 10, 16),
#  datetime.date(2021, 10, 15),
#  datetime.date(2021, 10, 14),
#  datetime.date(2021, 10, 13),
#  datetime.date(2021, 10, 12),
#  datetime.date(2021, 10, 11),
#  datetime.date(2021, 10, 10),
#  datetime.date(2021, 10, 9),
#  datetime.date(2021, 10, 8),
#  datetime.date(2021, 10, 7),
#  datetime.date(2021, 10, 6),
#  datetime.date(2021, 10, 5),
#  datetime.date(2021, 10, 4),
#  datetime.date(2021, 10, 3),
#  datetime.date(2021, 10, 2),
#  datetime.date(2021, 10, 1),
#  datetime.date(2021, 9, 30),
#  datetime.date(2021, 9, 29),
#  datetime.date(2021, 9, 28),
#  datetime.date(2021, 9, 27),
#  datetime.date(2021, 9, 26),
#  datetime.date(2021, 9, 25),
#  datetime.date(2021, 9, 24),
#  datetime.date(2021, 9, 23),
#  datetime.date(2021, 9, 22),
#  datetime.date(2021, 9, 21),
#  NaT,
#  datetime.date(2021, 9, 19),
#  datetime.date(2021, 9, 18),
#  datetime.date(2021, 9, 17),
#  datetime.date(2021, 9, 16),
#  datetime.date(2021, 9, 15),
#  datetime.date(2021, 9, 14),
#  datetime.date(2021, 9, 13),
#  datetime.date(2021, 9, 12),
#  datetime.date(2021, 9, 11),
#  datetime.date(2021, 9, 10),
#  datetime.date(2021, 9, 9),
#  datetime.date(2021, 9, 8),
#  datetime.date(2021, 9, 7),
#  datetime.date(2021, 9, 6),
#  datetime.date(2021, 9, 5),
#  NaT,
#  NaT,
#  NaT,
#  NaT,
#  NaT,
#  NaT,
#  NaT,
#  datetime.date(2021, 8, 15),
#  datetime.date(2021, 8, 14),
#  datetime.date(2021, 8, 13),
#  datetime.date(2021, 8, 12),
#  datetime.date(2021, 8, 11),
#  NaT,
#  NaT,
#  NaT,
#  NaT,
#  NaT,
#  NaT,
#  NaT,
#  NaT,
#  NaT,
#  NaT,
#  datetime.date(2021, 5, 17),
#  datetime.date(2021, 5, 16),
#  datetime.date(2021, 5, 15),
#  datetime.date(2021, 5, 14),
#  datetime.date(2021, 5, 13),
#  datetime.date(2021, 5, 12),
#  datetime.date(2021, 5, 11),
#  NaT,
#  datetime.date(2021, 5, 9),
#  datetime.date(2021, 5, 8),
#  datetime.date(2021, 5, 7),
#  datetime.date(2021, 5, 6),
#  datetime.date(2021, 5, 5),
#  datetime.date(2021, 5, 4),
#  datetime.date(2021, 5, 3),
#  datetime.date(2021, 5, 2),
#  datetime.date(2021, 5, 1),
#  datetime.date(2021, 4, 30),
#  datetime.date(2021, 4, 29),
#  datetime.date(2021, 4, 26),
#  datetime.date(2021, 4, 25),
#  datetime.date(2021, 4, 24),
#  datetime.date(2021, 4, 23),
#  datetime.date(2021, 4, 22),
#  datetime.date(2021, 4, 20),
#  datetime.date(2021, 4, 19),
#  datetime.date(2021, 4, 18),
#  datetime.date(2021, 4, 17),
#  datetime.date(2021, 4, 16),
#  datetime.date(2021, 4, 15),
#  datetime.date(2021, 4, 14),
#  datetime.date(2021, 4, 13),
#  datetime.date(2021, 4, 12),
#  datetime.date(2021, 4, 11),
#  datetime.date(2021, 4, 10),
#  datetime.date(2021, 4, 9),
#  datetime.date(2021, 4, 8),
#  NaT,
#  datetime.date(2021, 4, 6),
#  datetime.date(2021, 4, 5),
#  datetime.date(2021, 4, 4),
#  datetime.date(2021, 4, 3),
#  datetime.date(2021, 4, 2),
#  datetime.date(2021, 4, 1),
#  datetime.date(2021, 3, 31),
#  datetime.date(2021, 3, 30),
#  datetime.date(2021, 3, 29),
#  datetime.date(2021, 3, 28),
#  datetime.date(2021, 3, 27),
#  datetime.date(2021, 3, 23),
#  datetime.date(2021, 3, 22),
#  datetime.date(2021, 3, 21),
#  datetime.date(2021, 3, 20),
#  datetime.date(2021, 3, 19),
#  datetime.date(2021, 3, 18),
#  datetime.date(2021, 3, 17),
#  datetime.date(2021, 3, 16),
#  datetime.date(2021, 3, 15),
#  datetime.date(2021, 3, 14),
#  datetime.date(2021, 3, 13),
#  datetime.date(2021, 3, 12),
#  datetime.date(2021, 3, 11),
#  datetime.date(2021, 3, 10),
#  datetime.date(2021, 3, 9),
#  datetime.date(2021, 3, 8),
#  datetime.date(2021, 3, 7),
#  datetime.date(2021, 3, 6),
#  datetime.date(2021, 3, 5),
#  datetime.date(2021, 3, 4),
#  datetime.date(2021, 3, 3),
#  datetime.date(2021, 3, 2),
#  datetime.date(2021, 3, 1),
#  datetime.date(2021, 2, 28),
#  datetime.date(2021, 2, 27),
#  datetime.date(2021, 2, 26),
#  datetime.date(2021, 2, 25),
#  datetime.date(2021, 2, 24),
#  datetime.date(2021, 2, 23),
#  datetime.date(2021, 2, 22),
#  datetime.date(2021, 2, 21),
#  datetime.date(2021, 2, 20),
#  datetime.date(2021, 2, 19),
#  datetime.date(2021, 2, 18),
#  datetime.date(2021, 2, 17),
#  datetime.date(2021, 2, 16),
#  datetime.date(2021, 2, 15),
#  datetime.date(2021, 2, 14),
#  datetime.date(2021, 2, 13),
#  datetime.date(2021, 2, 12),
#  datetime.date(2021, 2, 11),
#  datetime.date(2021, 2, 10),
#  datetime.date(2021, 2, 9),
#  datetime.date(2021, 2, 8),
#  datetime.date(2021, 2, 7),
#  datetime.date(2021, 2, 6),
#  datetime.date(2021, 2, 5),
#  datetime.date(2021, 2, 4),
#  datetime.date(2021, 2, 3),
#  datetime.date(2021, 2, 2),
#  datetime.date(2021, 2, 1),
#  datetime.date(2021, 1, 31),
#  datetime.date(2021, 1, 30),
#  datetime.date(2021, 1, 29),
#  datetime.date(2021, 1, 28),
#  datetime.date(2021, 1, 27),
#  datetime.date(2021, 1, 26),
#  datetime.date(2021, 1, 25),
#  datetime.date(2021, 1, 24),
#  datetime.date(2021, 1, 23),
#  datetime.date(2021, 1, 22),
#  datetime.date(2021, 1, 21),
#  datetime.date(2021, 1, 20),
#  datetime.date(2021, 1, 19),
#  datetime.date(2021, 1, 18),
#  datetime.date(2021, 1, 17),
#  datetime.date(2021, 1, 16),
#  datetime.date(2021, 1, 15),
#  datetime.date(2021, 1, 14),
#  datetime.date(2021, 1, 13),
#  datetime.date(2021, 1, 12),
#  datetime.date(2021, 1, 11),
#  datetime.date(2021, 1, 10),
#  datetime.date(2021, 1, 9),
#  datetime.date(2021, 1, 8),
#  datetime.date(2021, 1, 7),
#  datetime.date(2021, 1, 6),
#  datetime.date(2021, 1, 5),
#  datetime.date(2021, 1, 4),
#  datetime.date(2021, 1, 3),
#  datetime.date(2021, 1, 2),
#  datetime.date(2021, 1, 1),
#  datetime.date(2020, 12, 31),
#  datetime.date(2020, 12, 30),
#  NaT,
#  datetime.date(2020, 12, 28),
#  datetime.date(2020, 12, 27),
#  datetime.date(2020, 12, 26),
#  datetime.date(2020, 12, 25),
#  NaT,
#  datetime.date(2020, 12, 23),
#  datetime.date(2020, 12, 22),
#  datetime.date(2020, 12, 21),
#  datetime.date(2020, 12, 20),
#  datetime.date(2020, 12, 19),
#  datetime.date(2020, 12, 18),
#  datetime.date(2020, 12, 17),
#  datetime.date(2020, 12, 16),
#  datetime.date(2020, 12, 15),
#  NaT,
#  datetime.date(2020, 12, 13),
#  datetime.date(2020, 12, 12),
#  datetime.date(2020, 12, 11),
#  datetime.date(2020, 12, 10),
#  datetime.date(2020, 12, 9),
#  datetime.date(2020, 12, 8),
#  datetime.date(2020, 12, 7),
#  datetime.date(2020, 12, 6),
#  datetime.date(2020, 12, 5),
#  datetime.date(2020, 12, 4),
#  datetime.date(2020, 12, 3),
#  datetime.date(2020, 12, 2),
#  datetime.date(2020, 12, 1),
#  datetime.date(2020, 11, 30),
#  datetime.date(2020, 11, 29),
#  datetime.date(2020, 11, 28),
#  datetime.date(2020, 11, 27),
#  datetime.date(2020, 11, 26),
#  datetime.date(2020, 11, 25),
#  datetime.date(2020, 11, 24),
#  datetime.date(2020, 11, 23),
#  datetime.date(2020, 11, 22),
#  datetime.date(2020, 11, 21),
#  datetime.date(2020, 11, 20),
#  datetime.date(2020, 11, 19),
#  datetime.date(2020, 11, 18),
#  datetime.date(2020, 11, 17),
#  datetime.date(2020, 11, 12),
#  datetime.date(2020, 11, 11),
#  datetime.date(2020, 11, 10),
#  datetime.date(2020, 11, 9),
#  datetime.date(2020, 11, 8),
#  datetime.date(2020, 5, 28),
#  datetime.date(2020, 5, 27),
#  datetime.date(2020, 5, 26),
#  datetime.date(2020, 5, 25),
#  datetime.date(2020, 5, 24),
#  datetime.date(2020, 5, 23),
#  datetime.date(2020, 5, 22),
#  datetime.date(2020, 5, 21),
#  datetime.date(2020, 5, 20),
#  datetime.date(2020, 5, 19),
#  datetime.date(2020, 5, 18),
#  datetime.date(2020, 5, 17),
#  datetime.date(2020, 5, 16),
#  datetime.date(2020, 5, 15),
#  datetime.date(2020, 5, 14),
#  datetime.date(2020, 5, 13),
#  datetime.date(2020, 5, 12),
#  datetime.date(2020, 5, 11),
#  datetime.date(2020, 5, 10),
#  datetime.date(2020, 5, 9),
#  datetime.date(2020, 5, 8),
#  datetime.date(2020, 5, 7),
#  datetime.date(2020, 5, 6),
#  datetime.date(2020, 5, 5),
#  datetime.date(2020, 5, 4),
#  datetime.date(2020, 5, 3),
#  datetime.date(2020, 5, 2),
#  datetime.date(2020, 5, 1),
#  datetime.date(2020, 4, 30),
#  datetime.date(2020, 4, 29),
#  datetime.date(2020, 4, 28),
#  datetime.date(2020, 4, 27),
#  datetime.date(2020, 4, 26),
#  datetime.date(2020, 4, 25),
#  datetime.date(2020, 4, 24),
#  datetime.date(2020, 4, 23),
#  datetime.date(2020, 4, 22),
#  datetime.date(2020, 4, 21),
#  datetime.date(2020, 4, 20),
#  datetime.date(2020, 4, 19),
#  datetime.date(2020, 4, 18),
#  datetime.date(2020, 4, 17),
#  NaT,
#  datetime.date(2019, 12, 4),
#  NaT,
#  datetime.date(2019, 12, 2),
#  datetime.date(2019, 12, 1),
#  datetime.date(2019, 11, 17),
#  datetime.date(2019, 11, 16),
#  datetime.date(2019, 11, 15),
#  datetime.date(2019, 11, 14),
#  NaT]

# %%
start_date = dates[-2]
end_date = dates[0]

# Create a boolean mask that identifies the rows in the dataframe that fall within the specified date range
mask = (df["Date"] >= start_date) & (df["Date"] <= end_date)

# Use the mask to filter the dataframe and select only the rows that fall within the date range
df_filtered = df[mask]

# Print the unique dates in the filtered dataframe
# print(df_filtered["Date"].unique())

# %%
import datetime

# %%
date_range = [start_date + datetime.timedelta(days=x) for x in range(0, (end_date-start_date).days)]

# Subtract the list of unique dates from the full range of dates to find the missing dates
missing_dates = [date for date in date_range if date not in df_filtered["Date"].unique()]

# Print the missing dates
print(missing_dates)
# Out:
# [datetime.date(2019, 11, 18), datetime.date(2019, 11, 19), datetime.date(2019, 11, 20), datetime.date(2019, 11, 21), datetime.date(2019, 11, 22), datetime.date(2019, 11, 23), datetime.date(2019, 11, 24), datetime.date(2019, 11, 25), datetime.date(2019, 11, 26), datetime.date(2019, 11, 27), datetime.date(2019, 11, 28), datetime.date(2019, 11, 29), datetime.date(2019, 11, 30), datetime.date(2019, 12, 3), datetime.date(2019, 12, 5), datetime.date(2019, 12, 6), datetime.date(2019, 12, 7), datetime.date(2019, 12, 8), datetime.date(2019, 12, 9), datetime.date(2019, 12, 10), datetime.date(2019, 12, 11), datetime.date(2019, 12, 12), datetime.date(2019, 12, 13), datetime.date(2019, 12, 14), datetime.date(2019, 12, 15), datetime.date(2019, 12, 16), datetime.date(2019, 12, 17), datetime.date(2019, 12, 18), datetime.date(2019, 12, 19), datetime.date(2019, 12, 20), datetime.date(2019, 12, 21), datetime.date(2019, 12, 22), datetime.date(2019, 12, 23), datetime.date(2019, 12, 24), datetime.date(2019, 12, 25), datetime.date(2019, 12, 26), datetime.date(2019, 12, 27), datetime.date(2019, 12, 28), datetime.date(2019, 12, 29), datetime.date(2019, 12, 30), datetime.date(2019, 12, 31), datetime.date(2020, 1, 1), datetime.date(2020, 1, 2), datetime.date(2020, 1, 3), datetime.date(2020, 1, 4), datetime.date(2020, 1, 5), datetime.date(2020, 1, 6), datetime.date(2020, 1, 7), datetime.date(2020, 1, 8), datetime.date(2020, 1, 9), datetime.date(2020, 1, 10), datetime.date(2020, 1, 11), datetime.date(2020, 1, 12), datetime.date(2020, 1, 13), datetime.date(2020, 1, 14), datetime.date(2020, 1, 15), datetime.date(2020, 1, 16), datetime.date(2020, 1, 17), datetime.date(2020, 1, 18), datetime.date(2020, 1, 19), datetime.date(2020, 1, 20), datetime.date(2020, 1, 21), datetime.date(2020, 1, 22), datetime.date(2020, 1, 23), datetime.date(2020, 1, 24), datetime.date(2020, 1, 25), datetime.date(2020, 1, 26), datetime.date(2020, 1, 27), datetime.date(2020, 1, 28), datetime.date(2020, 1, 29), datetime.date(2020, 1, 30), datetime.date(2020, 1, 31), datetime.date(2020, 2, 1), datetime.date(2020, 2, 2), datetime.date(2020, 2, 3), datetime.date(2020, 2, 4), datetime.date(2020, 2, 5), datetime.date(2020, 2, 6), datetime.date(2020, 2, 7), datetime.date(2020, 2, 8), datetime.date(2020, 2, 9), datetime.date(2020, 2, 10), datetime.date(2020, 2, 11), datetime.date(2020, 2, 12), datetime.date(2020, 2, 13), datetime.date(2020, 2, 14), datetime.date(2020, 2, 15), datetime.date(2020, 2, 16), datetime.date(2020, 2, 17), datetime.date(2020, 2, 18), datetime.date(2020, 2, 19), datetime.date(2020, 2, 20), datetime.date(2020, 2, 21), datetime.date(2020, 2, 22), datetime.date(2020, 2, 23), datetime.date(2020, 2, 24), datetime.date(2020, 2, 25), datetime.date(2020, 2, 26), datetime.date(2020, 2, 27), datetime.date(2020, 2, 28), datetime.date(2020, 2, 29), datetime.date(2020, 3, 1), datetime.date(2020, 3, 2), datetime.date(2020, 3, 3), datetime.date(2020, 3, 4), datetime.date(2020, 3, 5), datetime.date(2020, 3, 6), datetime.date(2020, 3, 7), datetime.date(2020, 3, 8), datetime.date(2020, 3, 9), datetime.date(2020, 3, 10), datetime.date(2020, 3, 11), datetime.date(2020, 3, 12), datetime.date(2020, 3, 13), datetime.date(2020, 3, 14), datetime.date(2020, 3, 15), datetime.date(2020, 3, 16), datetime.date(2020, 3, 17), datetime.date(2020, 3, 18), datetime.date(2020, 3, 19), datetime.date(2020, 3, 20), datetime.date(2020, 3, 21), datetime.date(2020, 3, 22), datetime.date(2020, 3, 23), datetime.date(2020, 3, 24), datetime.date(2020, 3, 25), datetime.date(2020, 3, 26), datetime.date(2020, 3, 27), datetime.date(2020, 3, 28), datetime.date(2020, 3, 29), datetime.date(2020, 3, 30), datetime.date(2020, 3, 31), datetime.date(2020, 4, 1), datetime.date(2020, 4, 2), datetime.date(2020, 4, 3), datetime.date(2020, 4, 4), datetime.date(2020, 4, 5), datetime.date(2020, 4, 6), datetime.date(2020, 4, 7), datetime.date(2020, 4, 8), datetime.date(2020, 4, 9), datetime.date(2020, 4, 10), datetime.date(2020, 4, 1 ...

# %% [markdown]
# This looks to be the most recent date when I started using my WHOOP again

# %%
start_date = datetime.date(2021, 9, 20)
end_date = datetime.date(2022, 11, 27)

# %%
date_range = [start_date + datetime.timedelta(days=x) for x in range(0, (end_date-start_date).days)]

# Subtract the list of unique dates from the full range of dates to find the missing dates
missing_dates = [date for date in date_range if date not in df_filtered["Date"].unique()]

# Print the missing dates
print(len(missing_dates))
# Out:
# 29

# %%
# Create a boolean mask that identifies the rows in the dataframe that fall within the specified date range
mask = (df["Date"] >= start_date) & (df["Date"] <= end_date)

# Use the mask to filter the dataframe and select only the rows that fall within the date range
df_recent = df[mask]

# Print the unique dates in the filtered dataframe
df_recent.head()
# Out:
#          Date  Resting heart rate (bpm)  Heart rate variability (ms)  \
# 1  2022-11-27                      65.0                         47.0
# 2  2022-11-26                      61.0                         50.0
# 3  2022-11-25                      58.0                         52.0
# 4  2022-11-24                      59.0                         56.0
# 5  2022-11-23                      57.0                         62.0
#
#    Skin temp (celsius)  Blood oxygen %  Energy burned (cal)  Max HR (bpm)  \
# 1                33.74           95.24               1740.0         126.0
# 2                33.60           97.17               2651.0         159.0
# 3                33.90           97.07               2984.0         159.0
# 4                32.10           98.25               2121.0         154.0
# 5                33.90           96.79               1984.0         128.0
#
#    Average HR (bpm)          Sleep onset           Wake onset  ...  \
# 1              76.0  2022-11-27 03:18:18  2022-11-27 10:52:02  ...
# 2              84.0  2022-11-26 03:51:55  2022-11-26 11:36:43  ...
# 3              83.0  2022-11-25 03:24:54  2022-11-25 11:58:44  ...
# 4              79.0  2022-11-24 03:17:20  2022-11-24 11:59:53  ...
# 5              73.0  2022-11-23 02:31:15  2022-11-23 09:36:37  ...
#
#    Asleep duration (min)  Light sleep duration (min)  \
# 1                  413.0                       218.0
# 2                  426.0                       187.0
# 3                  435.0                       200.0
# 4                  470.0                       244.0
# 5                  385.0                       186.0
#
#    Deep (SWS) duration (min)  REM duration (min)  Awake duration (min)  \
# 1                       88.0               107.0                  34.0
# 2                      109.0               130.0                  38.0
# 3                      107.0               128.0                  77.0
# 4                      111.0               115.0                  52.0
# 5                      103.0                96.0                  35.0
#
#    Sleep need (min)  Sleep debt (min)    Steps  Day Strain  Recovery score %
# 1             543.0              46.0   3603.0         5.0              36.0
# 2             535.0              30.0  12908.0        13.5              42.0
# 3             500.0              23.0  10299.0        14.8              45.0
# 4             523.0              51.0   5782.0         8.2              53.0
# 5             494.0              16.0   1112.0         4.9              72.0
#
# [5 rows x 22 columns]

# %%
df_recent.tail()
# Out:
#            Date  Resting heart rate (bpm)  Heart rate variability (ms)  \
# 403  2021-09-25                      53.0                         68.0
# 404  2021-09-24                      54.0                         62.0
# 405  2021-09-23                      54.0                         53.0
# 406  2021-09-22                      57.0                         50.0
# 407  2021-09-21                      57.0                         54.0
#
#      Skin temp (celsius)  Blood oxygen %  Energy burned (cal)  Max HR (bpm)  \
# 403                  NaN             NaN               1483.0         111.0
# 404                  NaN             NaN               2024.0         152.0
# 405                  NaN             NaN               1725.0         130.0
# 406                  NaN             NaN               2212.0         161.0
# 407                  NaN             NaN               2134.0         135.0
#
#      Average HR (bpm)          Sleep onset           Wake onset  ...  \
# 403              67.0  2021-09-25 00:15:13  2021-09-25 06:48:45  ...
# 404              66.0  2021-09-24 00:39:58  2021-09-24 10:30:25  ...
# 405              67.0  2021-09-23 03:23:20  2021-09-23 11:29:14  ...
# 406              71.0  2021-09-22 02:20:52  2021-09-22 09:47:06  ...
# 407              66.0  2021-09-21 02:15:20  2021-09-21 10:28:00  ...
#
#      Asleep duration (min)  Light sleep duration (min)  \
# 403                  351.0                       108.0
# 404                  525.0                       253.0
# 405                  450.0                       175.0
# 406                  409.0                       164.0
# 407                  451.0                       167.0
#
#      Deep (SWS) duration (min)  REM duration (min)  Awake duration (min)  \
# 403                      102.0               141.0                  42.0
# 404                      120.0               152.0                  65.0
# 405                      138.0               137.0                  35.0
# 406                      132.0               113.0                  32.0
# 407                      109.0               175.0                  41.0
#
#      Sleep need (min)  Sleep debt (min)   Steps  Day Strain  Recovery score %
# 403             477.0               0.0  1783.0         3.5              86.0
# 404             508.0              33.0  3381.0         6.8              83.0
# 405             524.0              44.0   637.0         4.9              54.0
# 406             503.0              23.0   899.0         8.1              50.0
# 407             500.0              28.0   645.0         8.4              60.0
#
# [5 rows x 22 columns]

# %% [markdown]
# ***
# ### NaN Handling

# %%
df_recent.columns
# Out:
# Index(['Date', 'Resting heart rate (bpm)', 'Heart rate variability (ms)',
#        'Skin temp (celsius)', 'Blood oxygen %', 'Energy burned (cal)',
#        'Max HR (bpm)', 'Average HR (bpm)', 'Sleep onset', 'Wake onset',
#        'Sleep performance %', 'Respiratory rate (rpm)',
#        'Asleep duration (min)', 'Light sleep duration (min)',
#        'Deep (SWS) duration (min)', 'REM duration (min)',
#        'Awake duration (min)', 'Sleep need (min)', 'Sleep debt (min)', 'Steps',
#        'Day Strain', 'Recovery score %'],
#       dtype='object')

# %%
df_recent.describe()
# Out:
#        Resting heart rate (bpm)  Heart rate variability (ms)  \
# count                405.000000                   405.000000
# mean                  57.007407                    62.664198
# std                    3.045439                     9.625195
# min                   50.000000                    32.000000
# 25%                   55.000000                    56.000000
# 50%                   57.000000                    62.000000
# 75%                   59.000000                    68.000000
# max                   79.000000                    94.000000
#
#        Skin temp (celsius)  Blood oxygen %  Energy burned (cal)  Max HR (bpm)  \
# count           288.000000      288.000000           405.000000    405.000000
# mean             33.043646       96.523576          2125.143210    150.323457
# std               0.563472        1.524935           289.655094     15.911001
# min              31.310000       87.500000           758.000000    111.000000
# 25%              32.700000       95.875000          1950.000000    140.000000
# 50%              33.030000       96.830000          2060.000000    150.000000
# 75%              33.500000       97.430000          2270.000000    160.000000
# max              34.600000      100.000000          3335.000000    199.000000
#
#        Average HR (bpm)  Sleep performance %  Respiratory rate (rpm)  \
# count        405.000000           405.000000              405.000000
# mean          71.812346            91.375309               13.334568
# std            4.318891            10.264684                0.305705
# min           62.000000            37.000000               12.700000
# 25%           68.000000            87.000000               13.100000
# 50%           72.000000            94.000000               13.300000
# 75%           75.000000           100.000000               13.500000
# max           88.000000           100.000000               15.600000
#
#        Asleep duration (min)  Light sleep duration (min)  \
# count             405.000000                  405.000000
# mean              459.945679                  206.407407
# std                63.178139                   39.471815
# min               195.000000                   80.000000
# 25%               428.000000                  182.000000
# 50%               462.000000                  205.000000
# 75%               499.000000                  230.000000
# max               699.000000                  379.000000
#
#        Deep (SWS) duration (min)  REM duration (min)  Awake duration (min)  \
# count                 405.000000          405.000000            405.000000
# mean                  112.311111          141.227160             41.943210
# std                    22.546695           30.061945             21.402536
# min                    46.000000           28.000000              4.000000
# 25%                    97.000000          123.000000             29.000000
# 50%                   111.000000          142.000000             39.000000
# 75%                   127.000000          162.000000             51.000000
# max                   179.000000          225.000000            243.000000
#
#        Sleep need (min)  Sleep debt (min)         Steps  Day Strain  \
# count        405.000000        405.000000    405.000000  405.000000
# mean         491.681481         20.844444   3966.338272    7.876543
# std           32.797681         23.943581   3302.809829    2.855777
# min          230.000000          0.000000    122.000000    3.500000
# 25%          476.000000          0.000000   1543.000000    5.400000
# 50%          491.000000         15.000000   3094.000000    7.100000
# 75%          509.000000         32.000000   5604.000000   10.100000
# max          610.000000        148.000000  17689.000000   16.000000
#
#        Recovery score %
# count        405.000000
# mean          68.503704
# std           18.187911
# min            1.000000
# 25%           55.000000
# 50%           71.000000
# 75%           83.000000
# max           99.000000

# %%
blood_mode = df_recent['Blood oxygen %'].mode()[0]

# %%
skin_mode = df_recent['Skin temp (celsius)'].mode()[0]

# %%
df_recent['Blood oxygen %'].replace(np.nan, blood_mode, inplace=True)
# Out:
# /Users/tinym/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
df_recent['Skin temp (celsius)'].replace(np.nan, skin_mode, inplace=True)

# %%
df_recent.isna().sum()
# Out:
# Date                           0
# Resting heart rate (bpm)       0
# Heart rate variability (ms)    0
# Skin temp (celsius)            0
# Blood oxygen %                 0
# Energy burned (cal)            0
# Max HR (bpm)                   0
# Average HR (bpm)               0
# Sleep onset                    0
# Wake onset                     0
# Sleep performance %            0
# Respiratory rate (rpm)         0
# Asleep duration (min)          0
# Light sleep duration (min)     0
# Deep (SWS) duration (min)      0
# REM duration (min)             0
# Awake duration (min)           0
# Sleep need (min)               0
# Sleep debt (min)               0
# Steps                          0
# Day Strain                     0
# Recovery score %               0
# dtype: int64

# %%
df_recent.describe()
# Out:
#        Resting heart rate (bpm)  Heart rate variability (ms)  \
# count                405.000000                   405.000000
# mean                  57.007407                    62.664198
# std                    3.045439                     9.625195
# min                   50.000000                    32.000000
# 25%                   55.000000                    56.000000
# 50%                   57.000000                    62.000000
# 75%                   59.000000                    68.000000
# max                   79.000000                    94.000000
#
#        Skin temp (celsius)  Blood oxygen %  Energy burned (cal)  Max HR (bpm)  \
# count           405.000000      405.000000           405.000000    405.000000
# mean             33.031037       96.661210          2125.143210    150.323457
# std               0.475335        1.303349           289.655094     15.911001
# min              31.310000       87.500000           758.000000    111.000000
# 25%              32.900000       96.400000          1950.000000    140.000000
# 50%              33.000000       97.000000          2060.000000    150.000000
# 75%              33.300000       97.130000          2270.000000    160.000000
# max              34.600000      100.000000          3335.000000    199.000000
#
#        Average HR (bpm)  Sleep performance %  Respiratory rate (rpm)  \
# count        405.000000           405.000000              405.000000
# mean          71.812346            91.375309               13.334568
# std            4.318891            10.264684                0.305705
# min           62.000000            37.000000               12.700000
# 25%           68.000000            87.000000               13.100000
# 50%           72.000000            94.000000               13.300000
# 75%           75.000000           100.000000               13.500000
# max           88.000000           100.000000               15.600000
#
#        Asleep duration (min)  Light sleep duration (min)  \
# count             405.000000                  405.000000
# mean              459.945679                  206.407407
# std                63.178139                   39.471815
# min               195.000000                   80.000000
# 25%               428.000000                  182.000000
# 50%               462.000000                  205.000000
# 75%               499.000000                  230.000000
# max               699.000000                  379.000000
#
#        Deep (SWS) duration (min)  REM duration (min)  Awake duration (min)  \
# count                 405.000000          405.000000            405.000000
# mean                  112.311111          141.227160             41.943210
# std                    22.546695           30.061945             21.402536
# min                    46.000000           28.000000              4.000000
# 25%                    97.000000          123.000000             29.000000
# 50%                   111.000000          142.000000             39.000000
# 75%                   127.000000          162.000000             51.000000
# max                   179.000000          225.000000            243.000000
#
#        Sleep need (min)  Sleep debt (min)         Steps  Day Strain  \
# count        405.000000        405.000000    405.000000  405.000000
# mean         491.681481         20.844444   3966.338272    7.876543
# std           32.797681         23.943581   3302.809829    2.855777
# min          230.000000          0.000000    122.000000    3.500000
# 25%          476.000000          0.000000   1543.000000    5.400000
# 50%          491.000000         15.000000   3094.000000    7.100000
# 75%          509.000000         32.000000   5604.000000   10.100000
# max          610.000000        148.000000  17689.000000   16.000000
#
#        Recovery score %
# count        405.000000
# mean          68.503704
# std           18.187911
# min            1.000000
# 25%           55.000000
# 50%           71.000000
# 75%           83.000000
# max           99.000000

# %%
df_recent["next_recovery"] = df_recent["Recovery score %"].shift(-1)
# Out:
# /var/folders/sk/rfg_lvqj5r5c204vs5zftlgw0000gn/T/ipykernel_62700/2100680934.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_recent["next_recovery"] = df_recent["Recovery score %"].shift(-1)

# %% [markdown]
# ***
# ### Time Handling in physio

# %% [markdown]
# Here I wanted to turn the time of waking up and falling asleep to simple hours so that it would potentially lead to some better insights

# %%
df_recent['Sleep onset'] = pd.to_datetime(df_recent['Sleep onset']) 
df_recent['Wake onset'] = pd.to_datetime(df_recent['Wake onset'])
# Out:
# /var/folders/sk/rfg_lvqj5r5c204vs5zftlgw0000gn/T/ipykernel_62700/2077816434.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_recent['Sleep onset'] = pd.to_datetime(df_recent['Sleep onset'])
# /var/folders/sk/rfg_lvqj5r5c204vs5zftlgw0000gn/T/ipykernel_62700/2077816434.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_recent['Wake onset'] = pd.to_datetime(df_recent['Wake onset'])

# %%
df_recent.dtypes
# Out:
# Date                                   object
# Resting heart rate (bpm)              float64
# Heart rate variability (ms)           float64
# Skin temp (celsius)                   float64
# Blood oxygen %                        float64
# Energy burned (cal)                   float64
# Max HR (bpm)                          float64
# Average HR (bpm)                      float64
# Sleep onset                    datetime64[ns]
# Wake onset                     datetime64[ns]
# Sleep performance %                   float64
# Respiratory rate (rpm)                float64
# Asleep duration (min)                 float64
# Light sleep duration (min)            float64
# Deep (SWS) duration (min)             float64
# REM duration (min)                    float64
# Awake duration (min)                  float64
# Sleep need (min)                      float64
# Sleep debt (min)                      float64
# Steps                                 float64
# Day Strain                            float64
# Recovery score %                      float64
# next_recovery                         float64
# dtype: object

# %%
df_recent['Hour sleep'] = df_recent['Sleep onset'].dt.hour
df_recent['Hour wake'] = df_recent['Wake onset'].dt.hour
# Out:
# /var/folders/sk/rfg_lvqj5r5c204vs5zftlgw0000gn/T/ipykernel_62700/945652353.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_recent['Hour sleep'] = df_recent['Sleep onset'].dt.hour
# /var/folders/sk/rfg_lvqj5r5c204vs5zftlgw0000gn/T/ipykernel_62700/945652353.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_recent['Hour wake'] = df_recent['Wake onset'].dt.hour

# %%
df_recent.head()
# Out:
#          Date  Resting heart rate (bpm)  Heart rate variability (ms)  \
# 1  2022-11-27                      65.0                         47.0
# 2  2022-11-26                      61.0                         50.0
# 3  2022-11-25                      58.0                         52.0
# 4  2022-11-24                      59.0                         56.0
# 5  2022-11-23                      57.0                         62.0
#
#    Skin temp (celsius)  Blood oxygen %  Energy burned (cal)  Max HR (bpm)  \
# 1                33.74           95.24               1740.0         126.0
# 2                33.60           97.17               2651.0         159.0
# 3                33.90           97.07               2984.0         159.0
# 4                32.10           98.25               2121.0         154.0
# 5                33.90           96.79               1984.0         128.0
#
#    Average HR (bpm)         Sleep onset          Wake onset  ...  \
# 1              76.0 2022-11-27 03:18:18 2022-11-27 10:52:02  ...
# 2              84.0 2022-11-26 03:51:55 2022-11-26 11:36:43  ...
# 3              83.0 2022-11-25 03:24:54 2022-11-25 11:58:44  ...
# 4              79.0 2022-11-24 03:17:20 2022-11-24 11:59:53  ...
# 5              73.0 2022-11-23 02:31:15 2022-11-23 09:36:37  ...
#
#    REM duration (min)  Awake duration (min)  Sleep need (min)  \
# 1               107.0                  34.0             543.0
# 2               130.0                  38.0             535.0
# 3               128.0                  77.0             500.0
# 4               115.0                  52.0             523.0
# 5                96.0                  35.0             494.0
#
#    Sleep debt (min)    Steps  Day Strain  Recovery score %  next_recovery  \
# 1              46.0   3603.0         5.0              36.0           42.0
# 2              30.0  12908.0        13.5              42.0           45.0
# 3              23.0  10299.0        14.8              45.0           53.0
# 4              51.0   5782.0         8.2              53.0           72.0
# 5              16.0   1112.0         4.9              72.0           69.0
#
#    Hour sleep  Hour wake
# 1           3         10
# 2           3         11
# 3           3         11
# 4           3         11
# 5           2          9
#
# [5 rows x 25 columns]

# %% [markdown]
# ***
# ### Pandas Profiling

# %%
# from pandas_profiling import ProfileReport
# profile = ProfileReport(df_recent, title='My WHOOP Data', explorative = True)
# profile

# %% [markdown]
# ***
# ### EDA of physio

# %%
plot_cor(df_recent);

# %%
sns.histplot(df_recent['Resting heart rate (bpm)'], kde=True);

# %%
sns.histplot(df_recent['Heart rate variability (ms)'], kde=True);

# %%
sns.histplot(df_recent['Hour wake'], kde=True);

# %%
sns.histplot(df_recent['Hour sleep'], kde=True);

# %%
df_recent['Adj Hour sleep'] = (df_recent['Hour sleep'] - 6)%12
# Out:
# /var/folders/sk/rfg_lvqj5r5c204vs5zftlgw0000gn/T/ipykernel_62700/1004411168.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_recent['Adj Hour sleep'] = (df_recent['Hour sleep'] - 6)%12

# %%
sns.histplot(df_recent['Adj Hour sleep'], kde=True);

# %%
sns.histplot(df_recent['Day Strain'], kde=True);

# %%
sns.histplot(df_recent['Recovery score %'], kde=True);

# %%
sns.regplot(data=df_recent, y='Recovery score %', x='Resting heart rate (bpm)')
# Out:
# <AxesSubplot:xlabel='Resting heart rate (bpm)', ylabel='Recovery score %'>

# %%
sns.regplot(data=df_recent, y='Recovery score %', x='Heart rate variability (ms)')
# Out:
# <AxesSubplot:xlabel='Heart rate variability (ms)', ylabel='Recovery score %'>

# %%
sns.regplot(data=df_recent, y='Day Strain', x='Average HR (bpm)')
# Out:
# <AxesSubplot:xlabel='Average HR (bpm)', ylabel='Day Strain'>

# %%
df_recent.columns
# Out:
# Index(['Date', 'Resting heart rate (bpm)', 'Heart rate variability (ms)',
#        'Skin temp (celsius)', 'Blood oxygen %', 'Energy burned (cal)',
#        'Max HR (bpm)', 'Average HR (bpm)', 'Sleep onset', 'Wake onset',
#        'Sleep performance %', 'Respiratory rate (rpm)',
#        'Asleep duration (min)', 'Light sleep duration (min)',
#        'Deep (SWS) duration (min)', 'REM duration (min)',
#        'Awake duration (min)', 'Sleep need (min)', 'Sleep debt (min)', 'Steps',
#        'Day Strain', 'Recovery score %', 'next_recovery', 'Hour sleep',
#        'Hour wake', 'Adj Hour sleep'],
#       dtype='object')

# %%
sns.regplot(data=df_recent, y='Day Strain', x='Steps')
# Out:
# <AxesSubplot:xlabel='Steps', ylabel='Day Strain'>

# %% [markdown]
# ***
# ### Time series analysis of RHR and HRV

# %%
df_sorted = df_recent.sort_values(by='Date').reset_index()

# %%
df_sorted.drop('index', axis=1, inplace=True)

# %%
df_sorted["next_recovery"] = df_sorted["Recovery score %"].shift(-1)

# %%
df_sorted.head()
# Out:
#          Date  Resting heart rate (bpm)  Heart rate variability (ms)  \
# 0  2021-09-21                      57.0                         54.0
# 1  2021-09-22                      57.0                         50.0
# 2  2021-09-23                      54.0                         53.0
# 3  2021-09-24                      54.0                         62.0
# 4  2021-09-25                      53.0                         68.0
#
#    Skin temp (celsius)  Blood oxygen %  Energy burned (cal)  Max HR (bpm)  \
# 0                 33.0            97.0               2134.0         135.0
# 1                 33.0            97.0               2212.0         161.0
# 2                 33.0            97.0               1725.0         130.0
# 3                 33.0            97.0               2024.0         152.0
# 4                 33.0            97.0               1483.0         111.0
#
#    Average HR (bpm)         Sleep onset          Wake onset  ...  \
# 0              66.0 2021-09-21 02:15:20 2021-09-21 10:28:00  ...
# 1              71.0 2021-09-22 02:20:52 2021-09-22 09:47:06  ...
# 2              67.0 2021-09-23 03:23:20 2021-09-23 11:29:14  ...
# 3              66.0 2021-09-24 00:39:58 2021-09-24 10:30:25  ...
# 4              67.0 2021-09-25 00:15:13 2021-09-25 06:48:45  ...
#
#    Awake duration (min)  Sleep need (min)  Sleep debt (min)   Steps  \
# 0                  41.0             500.0              28.0   645.0
# 1                  32.0             503.0              23.0   899.0
# 2                  35.0             524.0              44.0   637.0
# 3                  65.0             508.0              33.0  3381.0
# 4                  42.0             477.0               0.0  1783.0
#
#    Day Strain  Recovery score %  next_recovery  Hour sleep  Hour wake  \
# 0         8.4              60.0           50.0           2         10
# 1         8.1              50.0           54.0           2          9
# 2         4.9              54.0           83.0           3         11
# 3         6.8              83.0           86.0           0         10
# 4         3.5              86.0           89.0           0          6
#
#    Adj Hour sleep
# 0               8
# 1               8
# 2               9
# 3               6
# 4               6
#
# [5 rows x 26 columns]

# %%
df_sorted['SMA30'] = df_sorted['Resting heart rate (bpm)'].expanding(30).mean()

df_sorted[['Resting heart rate (bpm)', 'SMA30']].plot()
# Out:
# <AxesSubplot:>

# %%
df_sorted['SMA30HRV'] = df_sorted['Heart rate variability (ms)'].expanding(30).mean()

df_sorted[['Heart rate variability (ms)', 'SMA30HRV']].plot()
# Out:
# <AxesSubplot:>

# %%
df_sorted.columns
# Out:
# Index(['Date', 'Resting heart rate (bpm)', 'Heart rate variability (ms)',
#        'Skin temp (celsius)', 'Blood oxygen %', 'Energy burned (cal)',
#        'Max HR (bpm)', 'Average HR (bpm)', 'Sleep onset', 'Wake onset',
#        'Sleep performance %', 'Respiratory rate (rpm)',
#        'Asleep duration (min)', 'Light sleep duration (min)',
#        'Deep (SWS) duration (min)', 'REM duration (min)',
#        'Awake duration (min)', 'Sleep need (min)', 'Sleep debt (min)', 'Steps',
#        'Day Strain', 'Recovery score %', 'next_recovery', 'Hour sleep',
#        'Hour wake', 'Adj Hour sleep', 'SMA30', 'SMA30HRV'],
#       dtype='object')

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import acf
from statsmodels.tsa.stattools import adfuller, kpss
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_process import ArmaProcess
from statsmodels.tsa.arima.model import ARIMA
import pmdarima as pm
from statsmodels.tools.eval_measures import rmse

# %%
result1 = adfuller(df_sorted['Resting heart rate (bpm)'], autolag='AIC')
print(f'ADF Statistic: {result1[0]}')
print(f'p-value: {result1[1]}')
# Out:
# ADF Statistic: -3.008154122673226
# p-value: 0.034139892866278373

# %%
result2 = kpss(df_sorted['Resting heart rate (bpm)'])
print(f'KPSS Statistic: {result2[0]}')
print(f'p-value: {result2[1]}')
# Out:
# KPSS Statistic: 0.8732771696279304
# p-value: 0.01
# /Users/tinym/opt/anaconda3/envs/py3912/lib/python3.9/site-packages/statsmodels/tsa/stattools.py:2018: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   warnings.warn(

# %%
result1 = adfuller(df_sorted['Heart rate variability (ms)'], autolag='AIC')
print(f'ADF Statistic: {result1[0]}')
print(f'p-value: {result1[1]}')
# Out:
# ADF Statistic: -4.879375694552661
# p-value: 3.8245540314014515e-05

# %%
result2 = kpss(df_recent['Heart rate variability (ms)'])
print(f'KPSS Statistic: {result2[0]}')
print(f'p-value: {result2[1]}')
# Out:
# KPSS Statistic: 0.5149470109850081
# p-value: 0.03830022275112431

# %%
plot_acf(df_sorted['Resting heart rate (bpm)'], lags=30)

# Show the data as a plot (via matplotlib)
plt.show();

# %%
plot_acf(df_recent['Heart rate variability (ms)'], lags=30)

# Show the data as a plot (via matplotlib)
plt.show();

# %%
plot_pacf(df_sorted['Resting heart rate (bpm)'], alpha =0.05, lags=20)

plt.show();
# Out:
# /Users/tinym/opt/anaconda3/envs/py3912/lib/python3.9/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
plot_pacf(df_recent['Heart rate variability (ms)'], alpha =0.05, lags=20)

plt.show();

# %%
decomp_m = seasonal_decompose(df_sorted['Resting heart rate (bpm)'], model='multiplicative', period=27)

decomp_m.plot()
plt.show()

# %%
decomp_m = seasonal_decompose(df_sorted['Heart rate variability (ms)'], model='multiplicative', period=27)

decomp_m.plot()
plt.show()

# %%
stepwise_fit = pm.auto_arima(df_sorted['Resting heart rate (bpm)'], start_p=0, start_q=0,
                             m=15, max_p=30, max_q=30,
                             seasonal=True,
                             trace=True,
                             error_action='ignore',  # don't want to know if an order does not work
                             suppress_warnings=True,  # don't want convergence warnings
                             stepwise=True, scoring='mse')  # set to stepwise
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(1,0,1)[15] intercept   : AIC=2105.261, Time=0.21 sec
#  ARIMA(0,1,0)(0,0,0)[15] intercept   : AIC=2102.343, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[15] intercept   : AIC=2015.555, Time=0.12 sec
#  ARIMA(0,1,1)(0,0,1)[15] intercept   : AIC=1907.401, Time=0.20 sec
#  ARIMA(0,1,0)(0,0,0)[15]             : AIC=2100.358, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[15] intercept   : AIC=1906.591, Time=0.05 sec
# /Users/tinym/opt/anaconda3/envs/py3912/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# /Users/tinym/opt/anaconda3/envs/py3912/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
#  ARIMA(0,1,1)(1,0,0)[15] intercept   : AIC=1907.531, Time=0.16 sec
#  ARIMA(0,1,1)(1,0,1)[15] intercept   : AIC=1909.190, Time=0.41 sec
#  ARIMA(1,1,1)(0,0,0)[15] intercept   : AIC=1907.564, Time=0.07 sec
#  ARIMA(0,1,2)(0,0,0)[15] intercept   : AIC=1907.472, Time=0.09 sec
#  ARIMA(1,1,0)(0,0,0)[15] intercept   : AIC=2013.814, Time=0.03 sec
# /Users/tinym/opt/anaconda3/envs/py3912/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# /Users/tinym/opt/anaconda3/envs/py3912/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# /Users/tinym/opt/anaconda3/envs/py3912/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# /Users/tinym/opt/anaconda3/envs/py3912/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
#  ARIMA(1,1,2)(0,0,0)[15] intercept   : AIC=1906.154, Time=0.15 sec
#  ARIMA(1,1,2)(1,0,0)[15] intercept   : AIC=1906.829, Time=0.46 sec
# /Users/tinym/opt/anaconda3/envs/py3912/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
#  ARIMA(1,1,2)(0,0,1)[15] intercept   : AIC=1906.685, Time=0.54 sec
#  ARIMA(1,1,2)(1,0,1)[15] intercept   : AIC=1908.507, Time=0.87 sec
#  ARIMA(2,1,2)(0,0,0)[15] intercept   : AIC=1908.141, Time=0.19 sec
# /Users/tinym/opt/anaconda3/envs/py3912/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# /Users/tinym/opt/anaconda3/envs/py3912/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# /Users/tinym/opt/anaconda3/envs/py3912/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# /Users/tinym/opt/anaconda3/envs/py3912/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
#  ARIMA(1,1,3)(0,0,0)[15] intercept   : AIC=1908.142, Time=0.13 sec
#  ARIMA(0,1,3)(0,0,0)[15] intercept   : AIC=1908.964, Time=0.09 sec
#  ARIMA(2,1,1)(0,0,0)[15] intercept   : AIC=1909.106, Time=0.09 sec
# /Users/tinym/opt/anaconda3/envs/py3912/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# /Users/tinym/opt/anaconda3/envs/py3912/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
#  ARIMA(2,1,3)(0,0,0)[15] intercept   : AIC=1910.149, Time=0.17 sec
#  ARIMA(1,1,2)(0,0,0)[15]             : AIC=1904.472, Time=0.08 sec
#  ARIMA(1,1,2)(1,0,0)[15]             : AIC=1905.186, Time=0.22 sec
# /Users/tinym/opt/anaconda3/envs/py3912/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
#  ARIMA(1,1,2)(0,0,1)[15]             : AIC=1905.048, Time=0.28 sec
#  ARIMA(1,1,2)(1,0,1)[15]             : AIC=1906.876, Time=0.46 sec
#  ARIMA(0,1,2)(0,0,0)[15]             : AIC=1905.808, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,0)[15]             : AIC=1905.900, Time=0.04 sec
#  ARIMA(2,1,2)(0,0,0)[15]             : AIC=1906.454, Time=0.10 sec
# /Users/tinym/opt/anaconda3/envs/py3912/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# /Users/tinym/opt/anaconda3/envs/py3912/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# /Users/tinym/opt/anaconda3/envs/py3912/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# /Users/tinym/opt/anaconda3/envs/py3912/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
#  ARIMA(1,1,3)(0,0,0)[15]             : AIC=1906.455, Time=0.08 sec
#  ARIMA(0,1,1)(0,0,0)[15]             : AIC=1904.886, Time=0.02 sec
#  ARIMA(0,1,3)(0,0,0)[15]             : AIC=1907.265, Time=0.05 sec
#  ARIMA(2,1,1)(0,0,0)[15]             : AIC=1907.407, Time=0.04 sec
# /Users/tinym/opt/anaconda3/envs/py3912/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# /Users/tinym/opt/anaconda3/envs/py3912/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# /Users/tinym/opt/anaconda3/envs/py3912/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
#  ARIMA(2,1,3)(0,0,0)[15]             : AIC=1906.056, Time=0.32 sec
#
# Best model:  ARIMA(1,1,2)(0,0,0)[15]
# Total fit time: 5.776 seconds

# %%
opt = ARIMA(df_sorted['Resting heart rate (bpm)'], order=(1,1,2), seasonal_order=(0,0,0,15))
rm_opt = opt.fit()
print(rm_opt.summary())
# Out:
#                                   SARIMAX Results
# ====================================================================================
# Dep. Variable:     Resting heart rate (bpm)   No. Observations:                  405
# Model:                       ARIMA(1, 1, 2)   Log Likelihood                -948.236
# Date:                      Mon, 12 Dec 2022   AIC                           1904.472
# Time:                              14:45:41   BIC                           1920.477
# Sample:                                   0   HQIC                          1910.808
#                                       - 405
# Covariance Type:                        opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.7921      0.184     -4.312      0.000      -1.152      -0.432
# ma.L1          0.0025      0.159      0.015      0.988      -0.310       0.315
# ma.L2         -0.7325      0.131     -5.591      0.000      -0.989      -0.476
# sigma2         6.3800      0.214     29.792      0.000       5.960       6.800
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):              1396.28
# Prob(Q):                              0.91   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.68   Skew:                             1.60
# Prob(H) (two-sided):                  0.00   Kurtosis:                        11.52
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /Users/tinym/opt/anaconda3/envs/py3912/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /Users/tinym/opt/anaconda3/envs/py3912/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'

# %%
print(rmse(rm_opt.predict(), df_sorted['Resting heart rate (bpm)']))
# Out:
# 3.7942465528503106

# %%
df_sorted['Resting heart rate (bpm)'].describe()
# Out:
# count    405.000000
# mean      57.007407
# std        3.045439
# min       50.000000
# 25%       55.000000
# 50%       57.000000
# 75%       59.000000
# max       79.000000
# Name: Resting heart rate (bpm), dtype: float64

# %%
stepwise_fit = pm.auto_arima(df_sorted['Heart rate variability (ms)'], start_p=0, start_q=0,
                             m=15, max_p=30, max_q=30,
                             seasonal=True,
                             trace=True,
                             error_action='ignore',  # don't want to know if an order does not work
                             suppress_warnings=True,  # don't want convergence warnings
                             stepwise=True, scoring='mse')  # set to stepwise
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(1,0,1)[15] intercept   : AIC=2984.292, Time=0.23 sec
#  ARIMA(0,1,0)(0,0,0)[15] intercept   : AIC=2980.584, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[15] intercept   : AIC=2900.076, Time=0.14 sec
#  ARIMA(0,1,1)(0,0,1)[15] intercept   : AIC=2831.023, Time=0.18 sec
#  ARIMA(0,1,0)(0,0,0)[15]             : AIC=2978.585, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[15] intercept   : AIC=2830.010, Time=0.04 sec
# /Users/tinym/opt/anaconda3/envs/py3912/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# /Users/tinym/opt/anaconda3/envs/py3912/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
#  ARIMA(0,1,1)(1,0,0)[15] intercept   : AIC=2831.227, Time=0.17 sec
#  ARIMA(0,1,1)(1,0,1)[15] intercept   : AIC=2831.776, Time=0.40 sec
#  ARIMA(1,1,1)(0,0,0)[15] intercept   : AIC=2830.219, Time=0.07 sec
#  ARIMA(0,1,2)(0,0,0)[15] intercept   : AIC=2830.250, Time=0.07 sec
#  ARIMA(1,1,0)(0,0,0)[15] intercept   : AIC=2898.087, Time=0.04 sec
# /Users/tinym/opt/anaconda3/envs/py3912/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# /Users/tinym/opt/anaconda3/envs/py3912/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# /Users/tinym/opt/anaconda3/envs/py3912/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# /Users/tinym/opt/anaconda3/envs/py3912/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# /Users/tinym/opt/anaconda3/envs/py3912/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
#  ARIMA(1,1,2)(0,0,0)[15] intercept   : AIC=2834.008, Time=0.07 sec
#  ARIMA(0,1,1)(0,0,0)[15]             : AIC=2828.015, Time=0.02 sec
#  ARIMA(0,1,1)(1,0,0)[15]             : AIC=2829.231, Time=0.07 sec
# /Users/tinym/opt/anaconda3/envs/py3912/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
#  ARIMA(0,1,1)(0,0,1)[15]             : AIC=2829.027, Time=0.12 sec
#  ARIMA(0,1,1)(1,0,1)[15]             : AIC=2829.780, Time=0.20 sec
# /Users/tinym/opt/anaconda3/envs/py3912/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# /Users/tinym/opt/anaconda3/envs/py3912/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# /Users/tinym/opt/anaconda3/envs/py3912/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
#  ARIMA(1,1,1)(0,0,0)[15]             : AIC=2828.222, Time=0.04 sec
#  ARIMA(0,1,2)(0,0,0)[15]             : AIC=2828.254, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[15]             : AIC=2896.089, Time=0.02 sec
#  ARIMA(1,1,2)(0,0,0)[15]             : AIC=2829.743, Time=0.17 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[15]
# Total fit time: 2.164 seconds
# /Users/tinym/opt/anaconda3/envs/py3912/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1

# %%
opthrv = ARIMA(df_sorted['Heart rate variability (ms)'], order=(0,1,1), seasonal_order=(0,0,0,15))
rm_opt_hrv = opthrv.fit()
print(rm_opt_hrv.summary())
# Out:
#                                     SARIMAX Results
# =======================================================================================
# Dep. Variable:     Heart rate variability (ms)   No. Observations:                  405
# Model:                          ARIMA(0, 1, 1)   Log Likelihood               -1412.007
# Date:                         Mon, 12 Dec 2022   AIC                           2828.015
# Time:                                 14:45:43   BIC                           2836.018
# Sample:                                      0   HQIC                          2831.183
#                                          - 405
# Covariance Type:                           opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.7218      0.031    -23.102      0.000      -0.783      -0.661
# sigma2        63.4616      4.279     14.833      0.000      55.076      71.847
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.67   Jarque-Bera (JB):                 5.44
# Prob(Q):                              0.41   Prob(JB):                         0.07
# Heteroskedasticity (H):               1.01   Skew:                            -0.27
# Prob(H) (two-sided):                  0.96   Kurtosis:                         3.18
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
print(rmse(rm_opt_hrv.predict(), df_sorted['Heart rate variability (ms)']))
# Out:
# 8.399795761967422

# %%
df_sorted['Heart rate variability (ms)'].describe()
# Out:
# count    405.000000
# mean      62.664198
# std        9.625195
# min       32.000000
# 25%       56.000000
# 50%       62.000000
# 75%       68.000000
# max       94.000000
# Name: Heart rate variability (ms), dtype: float64

# %%
rm_opt.forecast(steps=20)
# Out:
# 405    59.821831
# 406    59.475290
# 407    59.749768
# 408    59.532368
# 409    59.704560
# 410    59.568175
# 411    59.676199
# 412    59.590638
# 413    59.658406
# 414    59.604731
# 415    59.647245
# 416    59.613571
# 417    59.640242
# 418    59.619118
# 419    59.635849
# 420    59.622597
# 421    59.633094
# 422    59.624780
# 423    59.631365
# 424    59.626149
# Name: predicted_mean, dtype: float64

# %%
rm_opt_hrv.forecast(steps=20)
# Out:
# 405    53.549658
# 406    53.549658
# 407    53.549658
# 408    53.549658
# 409    53.549658
# 410    53.549658
# 411    53.549658
# 412    53.549658
# 413    53.549658
# 414    53.549658
# 415    53.549658
# 416    53.549658
# 417    53.549658
# 418    53.549658
# 419    53.549658
# 420    53.549658
# 421    53.549658
# 422    53.549658
# 423    53.549658
# 424    53.549658
# Name: predicted_mean, dtype: float64

# %% [markdown]
# ***
# ### Recovery Regression

# %%
# from sklearn.feature_selection import VarianceThreshold
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel

# %% [markdown]
# #### Next day recovery prediction

# %%
df_sorted["next_sleep"] = df_sorted['Asleep duration (min)'].shift(-1)
df_sorted = df_sorted[df_sorted['next_recovery'].notna()]
df_sorted = df_sorted[df_sorted['Asleep duration (min)'].notna()]
X = df_sorted.drop(['next_recovery', 'Sleep onset', 'Wake onset', 'Date'], axis = 1)
y = df_sorted['next_recovery']

# %%
X.fillna(method='backfill', inplace=True)

# %%
X.isna().sum()
# Out:
# Resting heart rate (bpm)       0
# Heart rate variability (ms)    0
# Skin temp (celsius)            0
# Blood oxygen %                 0
# Energy burned (cal)            0
# Max HR (bpm)                   0
# Average HR (bpm)               0
# Sleep performance %            0
# Respiratory rate (rpm)         0
# Asleep duration (min)          0
# Light sleep duration (min)     0
# Deep (SWS) duration (min)      0
# REM duration (min)             0
# Awake duration (min)           0
# Sleep need (min)               0
# Sleep debt (min)               0
# Steps                          0
# Day Strain                     0
# Recovery score %               0
# Hour sleep                     0
# Hour wake                      0
# Adj Hour sleep                 0
# SMA30                          0
# SMA30HRV                       0
# next_sleep                     1
# dtype: int64

# %%
X.dtypes
# Out:
# Resting heart rate (bpm)       float64
# Heart rate variability (ms)    float64
# Skin temp (celsius)            float64
# Blood oxygen %                 float64
# Energy burned (cal)            float64
# Max HR (bpm)                   float64
# Average HR (bpm)               float64
# Sleep performance %            float64
# Respiratory rate (rpm)         float64
# Asleep duration (min)          float64
# Light sleep duration (min)     float64
# Deep (SWS) duration (min)      float64
# REM duration (min)             float64
# Awake duration (min)           float64
# Sleep need (min)               float64
# Sleep debt (min)               float64
# Steps                          float64
# Day Strain                     float64
# Recovery score %               float64
# Hour sleep                       int64
# Hour wake                        int64
# Adj Hour sleep                   int64
# SMA30                          float64
# SMA30HRV                       float64
# next_sleep                     float64
# dtype: object

# %%
SFM = SelectFromModel(estimator=RandomForestClassifier())
sel = SFM.fit(X, y)
selected_feat= X.columns[(sel.get_support())]
print(selected_feat)
# Out:
# Index(['Heart rate variability (ms)', 'Blood oxygen %', 'Energy burned (cal)',
#        'Max HR (bpm)', 'Asleep duration (min)', 'Light sleep duration (min)',
#        'Deep (SWS) duration (min)', 'REM duration (min)',
#        'Awake duration (min)', 'Sleep need (min)', 'Steps', 'Recovery score %',
#        'SMA30', 'SMA30HRV', 'next_sleep'],
#       dtype='object')

# %%
X = X.loc[: , selected_feat]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .33, random_state = 42)

# %%
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import linear_model

# %%
y.head()
# Out:
# 0    50.0
# 1    54.0
# 2    83.0
# 3    86.0
# 4    89.0
# Name: next_recovery, dtype: float64

# %%
y.plot()
# Out:
# <AxesSubplot: >

# %%
from tpot import TPOTRegressor

tpot = TPOTRegressor(generations=5, population_size=50, verbosity=2, random_state=42)
tpot.fit(X_train, y_train)
print(tpot.score(X_test, y_test))

tpot.export('tpot_ml_pipeline.py')
# Out:
#
# Generation 1 - Current best internal CV score: -80.80955914912553
#
# Generation 2 - Current best internal CV score: -69.69581244177242
#
# Generation 3 - Current best internal CV score: -69.69581244177242
#
# Generation 4 - Current best internal CV score: -69.69581244177242
#
# Generation 5 - Current best internal CV score: -69.69581244177242
#
# Best pipeline: XGBRegressor(input_matrix, learning_rate=0.1, max_depth=8, min_child_weight=6, n_estimators=100, n_jobs=1, objective=reg:squarederror, subsample=0.6000000000000001, verbosity=0)
# -64.6405578090286
# /Users/tinym/opt/anaconda3/envs/py3912/lib/python3.9/site-packages/sklearn/metrics/_scorer.py:765: FutureWarning: sklearn.metrics.SCORERS is deprecated and will be removed in v1.3. Please use sklearn.metrics.get_scorer_names to get a list of available scorers and sklearn.metrics.get_metric to get scorer.
#   warnings.warn(

# %%
from sklearn.linear_model import LassoLarsCV, ElasticNetCV
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.pipeline import make_pipeline
from tpot.builtins import StackingEstimator
from sklearn.preprocessing import MinMaxScaler

# %%
exported_pipeline = make_pipeline(
    MinMaxScaler(),
    LassoLarsCV(normalize=False)
)

exported_pipeline.fit(X_train, y_train)
results = exported_pipeline.predict(X_test)

# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(y_test, results))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(y_test, results))
# Out:
# Mean squared error: 114.93
# Coefficient of determination: 0.65

# %%
regr = linear_model.LinearRegression()
regr.fit(X_train, y_train)
y_pred = regr.predict(X_test)

print("Coefficients: \n", regr.coef_)
# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(y_test, y_pred))
# Out:
# Coefficients:
#  [ 2.29199654e-02 -3.32991245e-02  1.89262899e-01 -4.26427346e-02
#   1.82642082e-03  1.40783289e+00 -6.09165887e-03 -4.26678198e-02
#   7.16543589e-02 -2.21265773e-01  6.63224412e+00 -3.12383855e+00
#  -4.09929368e-03 -4.85847948e-05]
# Mean squared error: 114.49
# Coefficient of determination: 0.65

# %%
from sklearn.linear_model import SGDRegressor
from sklearn.preprocessing import StandardScaler

# %%
reg = make_pipeline(StandardScaler(),
                    SGDRegressor(max_iter=1000, tol=1e-3))
reg.fit(X_train, y_train)
y_pred = reg.predict(X_test)

# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(y_test, y_pred))
# Out:
# Mean squared error: 115.73
# Coefficient of determination: 0.65

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from tpot.builtins import StackingEstimator
from tpot.export_utils import set_param_recursive

# %%
training_features, testing_features, training_target, testing_target = \
            train_test_split(X, y, random_state=42)

exported_pipeline = make_pipeline(
    StackingEstimator(estimator=ElasticNetCV(l1_ratio=0.75, tol=0.01)),
    StackingEstimator(estimator=SGDRegressor(alpha=0.001, eta0=0.01, fit_intercept=False, l1_ratio=0.25, learning_rate="invscaling", loss="squared_error", penalty="elasticnet", power_t=100.0)),
    RandomForestRegressor(bootstrap=True, max_features=0.4, min_samples_leaf=16, min_samples_split=14, n_estimators=100)
)
# Fix random state for all the steps in exported pipeline
set_param_recursive(exported_pipeline.steps, 'random_state', 42)

exported_pipeline.fit(X_train, y_train)
results = exported_pipeline.predict(X_test)

# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(y_test, y_pred))
# Out:
# Mean squared error: 303.62
# Coefficient of determination: 0.01
# /Users/tinym/opt/anaconda3/envs/py3912/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but ElasticNetCV was fitted with feature names
#   warnings.warn(
# /Users/tinym/opt/anaconda3/envs/py3912/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but ElasticNetCV was fitted with feature names
#   warnings.warn(

# %% [markdown]
# #### Current day recovery

# %%
X = df_sorted.drop(['Recovery score %', 'next_sleep', 'next_recovery', 'Sleep onset', 'Wake onset', 'Date'], axis = 1)
y = df_sorted['Recovery score %']

# %%
X.fillna(method='backfill', inplace=True)

# %%
X.isna().sum()
# Out:
# Resting heart rate (bpm)       0
# Heart rate variability (ms)    0
# Skin temp (celsius)            0
# Blood oxygen %                 0
# Energy burned (cal)            0
# Max HR (bpm)                   0
# Average HR (bpm)               0
# Sleep performance %            0
# Respiratory rate (rpm)         0
# Asleep duration (min)          0
# Light sleep duration (min)     0
# Deep (SWS) duration (min)      0
# REM duration (min)             0
# Awake duration (min)           0
# Sleep need (min)               0
# Sleep debt (min)               0
# Steps                          0
# Day Strain                     0
# Hour sleep                     0
# Hour wake                      0
# Adj Hour sleep                 0
# SMA30                          0
# SMA30HRV                       0
# dtype: int64

# %%
X.dtypes
# Out:
# Resting heart rate (bpm)       float64
# Heart rate variability (ms)    float64
# Skin temp (celsius)            float64
# Blood oxygen %                 float64
# Energy burned (cal)            float64
# Max HR (bpm)                   float64
# Average HR (bpm)               float64
# Sleep performance %            float64
# Respiratory rate (rpm)         float64
# Asleep duration (min)          float64
# Light sleep duration (min)     float64
# Deep (SWS) duration (min)      float64
# REM duration (min)             float64
# Awake duration (min)           float64
# Sleep need (min)               float64
# Sleep debt (min)               float64
# Steps                          float64
# Day Strain                     float64
# Hour sleep                       int64
# Hour wake                        int64
# Adj Hour sleep                   int64
# SMA30                          float64
# SMA30HRV                       float64
# dtype: object

# %%
SFM = SelectFromModel(estimator=RandomForestClassifier())
sel = SFM.fit(X, y)
selected_feat= X.columns[(sel.get_support())].union(['Resting heart rate (bpm)'])
print(selected_feat)
# Out:
# Index(['Asleep duration (min)', 'Awake duration (min)', 'Day Strain',
#        'Deep (SWS) duration (min)', 'Energy burned (cal)',
#        'Heart rate variability (ms)', 'Light sleep duration (min)',
#        'Max HR (bpm)', 'REM duration (min)', 'Resting heart rate (bpm)',
#        'SMA30', 'SMA30HRV', 'Sleep need (min)', 'Steps'],
#       dtype='object')

# %%
X = X.loc[: , selected_feat]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .2, random_state = 42)

# %%
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import linear_model

# %%
y.head()
# Out:
# 0    60.0
# 1    50.0
# 2    54.0
# 3    83.0
# 4    86.0
# Name: Recovery score %, dtype: float64

# %%
y.plot()
# Out:
# <AxesSubplot:>

# %%
from tpot import TPOTRegressor

tpot = TPOTRegressor(generations=5, population_size=50, verbosity=2, random_state=42)
tpot.fit(X_train, y_train)
print(tpot.score(X_test, y_test))

tpot.export('tpot_ml_pipeline1.py')
# Out:
#
# Generation 1 - Current best internal CV score: -80.80955914912553
#
# Generation 2 - Current best internal CV score: -69.69581244177242
#
# Generation 3 - Current best internal CV score: -69.69581244177242
#
# Generation 4 - Current best internal CV score: -69.69581244177242
#
# Generation 5 - Current best internal CV score: -69.69581244177242
#
# Best pipeline: XGBRegressor(input_matrix, learning_rate=0.1, max_depth=8, min_child_weight=6, n_estimators=100, n_jobs=1, objective=reg:squarederror, subsample=0.6000000000000001, verbosity=0)
# -64.6405578090286
# /Users/tinym/opt/anaconda3/envs/py3912/lib/python3.9/site-packages/sklearn/metrics/_scorer.py:765: FutureWarning: sklearn.metrics.SCORERS is deprecated and will be removed in v1.3. Please use sklearn.metrics.get_scorer_names to get a list of available scorers and sklearn.metrics.get_metric to get scorer.
#   warnings.warn(

# %%
from sklearn.linear_model import LassoLarsCV, ElasticNetCV
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.pipeline import make_pipeline
# from tpot.builtins import StackingEstimator
from sklearn.preprocessing import MinMaxScaler
from xgboost import XGBRegressor

# %%
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.linear_model import ElasticNetCV
# from tpot.builtins import StackingEstimator

# %%
exported_pipeline = XGBRegressor(learning_rate=0.1, max_depth=8, min_child_weight=6, n_estimators=100, n_jobs=1, 
                                    objective="reg:squarederror", subsample=0.6000000000000001, verbosity=0)

exported_pipeline.fit(X_train, y_train)
results = exported_pipeline.predict(X_test)

# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(y_test, results))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(y_test, results))
# Out:
# Mean squared error: 60.10
# Coefficient of determination: 0.82

# %%
for i, val in enumerate(X.columns):
    print(val, ":", exported_pipeline.coef_[i])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/sk/rfg_lvqj5r5c204vs5zftlgw0000gn/T/ipykernel_62700/1238638040.py in <module>
#       1 for i, val in enumerate(X.columns):
# ----> 2     print(val, ":", exported_pipeline.coef_[i])
#
# ~/opt/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py in coef_(self)
#    1338         """
#    1339         if self.get_params()["booster"] != "gblinear":
# -> 1340             raise AttributeError(
#    1341                 f"Coefficients are not defined for Booster type {self.booster}"
#    1342             )
#
# AttributeError: Coefficients are not defined for Booster type None

# %%
reg = LassoLarsCV()
regi = reg.fit(X_train, y_train) 
y_pred = regi.predict(X_test)

# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(y_test, y_pred))
# Out:
# /Users/tinym/opt/anaconda3/envs/py3912/lib/python3.9/site-packages/sklearn/linear_model/_base.py:133: FutureWarning: The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsCV())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# Mean squared error: 117.08
# Coefficient of determination: 0.64

# %%
regr = linear_model.LinearRegression()
regr.fit(X_train, y_train)
y_pred = regr.predict(X_test)

for i in range(len(selected_feat)):
    print(selected_feat[i], ":", regr.coef_[i])

# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(y_test, y_pred))
# Out:
# Asleep duration (min) : 0.022919965402613134
# Awake duration (min) : -0.03329912445620992
# Day Strain : 0.18926289894811343
# Deep (SWS) duration (min) : -0.04264273457966428
# Energy burned (cal) : 0.0018264208154702005
# Heart rate variability (ms) : 1.4078328896724845
# Light sleep duration (min) : -0.006091658868771216
# Max HR (bpm) : -0.042667819843232764
# REM duration (min) : 0.0716543588510774
# Resting heart rate (bpm) : -0.22126577259755797
# SMA30 : 6.632244119232016
# SMA30HRV : -3.123838549311917
# Sleep need (min) : -0.004099293684892948
# Steps : -4.858479484894443e-05
# Mean squared error: 114.49
# Coefficient of determination: 0.65
